# %%
#!/usr/bin/env python3
# triangulation.py (patched - EKF tuning, logging, velocity reset)
import cv2, zmq, numpy as np, time, threading, queue, traceback, sys, os
from collections import deque, defaultdict
import math
import json

# ---------- Config ----------
ZMQ_ADDR = "tcp://localhost:5555"
SUB_TOPICS = [b"kreo1", b"kreo2"]
FPS_WINDOW = 1.0        # seconds for fps moving window
DISPLAY_FPS = 20
VISUALIZE = True     # show tiled view window

STATIC_TAG_IDS = [0,1,2,3]
TAG_POSITIONS = {
    0: np.array([0.9, 0.0, 0.0], dtype=float),
    1: np.array([0.0, 0.0, 0.0], dtype=float),
    2: np.array([0.9, 0.9, 0.0], dtype=float),
    3: np.array([0.0, 1.2, 0.0], dtype=float)
}
TAG_SIZES = {0: 0.099, 1: 0.096, 2: 0.096, 3: 0.096, 4: 0.096, 5: 0.096}
CALIB_FRAMES = 30
CALIB_DIR = "../calibration/"

# ---------- EKF & prediction logging config ----------
g = 9.814  # gravity (m/s^2)

# Robot limits (tune to your robot)
robot_max_speed = 1.0    # m/s
robot_max_accel = 1.0    # m/s^2

# Tag height and floor z
TAG_MOUNT_HEIGHT = 0.075   # 7.5 cm
FLOOR_Z = 0.0

_PRED_LOG_PATH = "predictions_log.txt"

# ---------- Detection params ----------
DICT_TYPE = cv2.aruco.DICT_APRILTAG_36h11

def create_april_detector():
    aruco_dict = cv2.aruco.getPredefinedDictionary(DICT_TYPE)
    params = cv2.aruco.DetectorParameters()
    params.adaptiveThreshWinSizeMin = 3
    params.adaptiveThreshWinSizeMax = 35
    params.adaptiveThreshWinSizeStep = 2
    params.cornerRefinementMethod = cv2.aruco.CORNER_REFINE_SUBPIX
    params.cornerRefinementWinSize = 7
    params.cornerRefinementMaxIterations = 50
    params.cornerRefinementMinAccuracy = 0.01
    params.minMarkerPerimeterRate = 0.02
    params.maxMarkerPerimeterRate = 6.0
    params.polygonalApproxAccuracyRate = 0.02
    params.adaptiveThreshConstant = 7
    return cv2.aruco.ArucoDetector(aruco_dict, params)

orange_hsvVals = {'hmin': 0,  'smin': 94,  'vmin': 156, 'hmax': 12,  'smax': 255, 'vmax': 255}
purple_hsvVals = {'hmin': 113,'smin': 78,  'vmin': 3,   'hmax': 129, 'smax': 255, 'vmax': 255}

MIN_AREA = 150
MAX_AREA = 20000
CIRCULARITY_MIN = 0.25
ASPECT_RATIO_MAX = 2.0
MAX_DETECTIONS_PER_CAM = 12

# ---------- Helpers ----------
def fmt_ts(ts):
    return time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(ts)) + f".{int((ts%1)*1000):03d}"

def recv_latest(sub):
    msg = None
    while True:
        try:
            msg = sub.recv_multipart(flags=zmq.NOBLOCK)
        except zmq.Again:
            break
    return msg

def update_fps(camera, cam_ts):
    dq = fps_windows[camera]
    dq.append(cam_ts)
    while dq and (cam_ts - dq[0]) > FPS_WINDOW:
        dq.popleft()
    fps = len(dq) / FPS_WINDOW
    return fps

def load_camera_calib(cam_name):
    path = os.path.join(CALIB_DIR, f'camera_calibration_{cam_name}.npz')
    if not os.path.exists(path):
        raise FileNotFoundError(path)
    calib = np.load(path)
    camera_matrix = calib["cameraMatrix"]
    dist_coeffs = calib['distCoeffs']
    print("[INFO] Loaded calibrated camera parameters")
    return camera_matrix, dist_coeffs

def build_tag_world_map_from_centers(tag_centers, tag_sizes):
    out = {}
    for tid, center in tag_centers.items():
        size = tag_sizes.get(tid, tag_sizes.get(1))
        half = float(size) / 2.0
        local = np.array([
            [-half,  half, 0.0],
            [ half,  half, 0.0],
            [ half, -half, 0.0],
            [-half, -half, 0.0],
        ], dtype=np.float64)
        corners_world = (local + center.reshape(1,3)).astype(np.float64)
        out[tid] = corners_world
    return out

TAG_WORLD_MAP = build_tag_world_map_from_centers(TAG_POSITIONS, TAG_SIZES)

# ---------- EKF, robot-center helpers, prediction logging ----------
class BallEKF:
    """
    6-state EKF: [X, Y, Z, Vx, Vy, Vz].
    Tuned: pos_sigma=0.02 m, accel_sigma=7.0 m/s^2, vel_sigma=1.0 m/s.
    """
    def __init__(self, pos_sigma=0.02, vel_sigma=1.0, accel_sigma=7.0):
        self.x = None
        self.P = None
        self.last_ts = None
        self.pos_sigma = float(pos_sigma)
        self.vel_sigma = float(vel_sigma)
        self.accel_sigma = float(accel_sigma)
        # thresholds
        self.z_jump_thresh = 0.30  # if measured z differs from predicted z by >0.30 m -> reset velocity

    def init_from_measurement(self, pos, ts):
        pos = np.asarray(pos, dtype=np.float64).reshape(3,)
        self.x = np.zeros((6,), dtype=np.float64)
        self.x[0:3] = pos
        self.x[3:6] = 0.0
        pos_var = (self.pos_sigma)**2
        vel_var = (self.vel_sigma)**2
        self.P = np.diag([pos_var, pos_var, pos_var, vel_var, vel_var, vel_var])
        self.last_ts = float(ts)

    def _build_Q(self, dt):
        sa = float(self.accel_sigma)
        dt2 = dt*dt
        dt3 = dt2*dt
        qpos = (dt3 / 3.0) * (sa**2)
        qposvel = (dt2 / 2.0) * (sa**2)
        qvel = dt * (sa**2)
        Q = np.zeros((6,6), dtype=np.float64)
        Q[0,0] = qpos; Q[0,3] = qposvel
        Q[1,1] = qpos; Q[1,4] = qposvel
        Q[2,2] = qpos; Q[2,5] = qposvel
        Q[3,0] = qposvel; Q[3,3] = qvel
        Q[4,1] = qposvel; Q[4,4] = qvel
        Q[5,2] = qposvel; Q[5,5] = qvel
        return Q

    def predict(self, dt):
        if self.x is None:
            return
        x = self.x.copy()
        x[0] += x[3] * dt
        x[1] += x[4] * dt
        x[2] += x[5] * dt - 0.5 * g * dt * dt
        x[3] += 0.0
        x[4] += 0.0
        x[5] += -g * dt
        self.x = x

        F = np.eye(6,6)
        F[0,3] = dt; F[1,4] = dt; F[2,5] = dt

        Q = self._build_Q(dt)
        self.P = F @ self.P @ F.T + Q
        self.last_ts = (self.last_ts + dt) if self.last_ts is not None else None

    def update(self, meas_pos, meas_R=None, meas_ts=None):
        t = meas_ts if meas_ts is not None else time.time()
        z = np.asarray(meas_pos, dtype=np.float64).reshape(3,)
        if self.x is None:
            self.init_from_measurement(z, t)
            return True

        # If measurement is newer, predict forward to that timestamp
        if self.last_ts is not None and t > self.last_ts:
            self.predict(t - self.last_ts)

        # velocity-reset if measurement z deviates too much from predicted z
        z_meas = float(z[2])
        z_pred = float(self.x[2])

        if abs(z_meas - z_pred) > self.z_jump_thresh:
            # reset velocity estimates and inflate their covariances
            self.x[3:6] = 0.0
            large_vel_var = (self.vel_sigma * 4.0)**2
            for i in range(3,6):
                self.P[i,i] = max(self.P[i,i], large_vel_var)
            print(f"[EKF] large Z jump: meas_z={z_meas:.3f}, pred_z={z_pred:.3f} -> resetting velocities")
        
        H = np.zeros((3,6), dtype=np.float64)
        H[0,0] = 1; H[1,1] = 1; H[2,2] = 1

        if meas_R is None:
            R = np.diag([self.pos_sigma**2]*3)
        else:
            R = np.asarray(meas_R, dtype=np.float64)

        z_pred_vec = H @ self.x
        r = z - z_pred_vec
        S = H @ self.P @ H.T + R
        try:
            S_inv = np.linalg.inv(S)
        except np.linalg.LinAlgError:
            return False
        d2 = float(r.T @ S_inv @ r)
        # gating: 99% chi-square 3DOF ~ 11.34
        if d2 > 11.34:
            # outlier
            print(f"[EKF] measurement gated out d2={d2:.2f}")
            return False

        K = self.P @ H.T @ S_inv
        self.x = self.x + K @ r
        self.P = (np.eye(6) - K @ H) @ self.P
        self.last_ts = t
        return True

    def predict_future(self, tau):
        if self.x is None:
            return None
        s = self.x.copy()
        px = s[0] + s[3]*tau
        py = s[1] + s[4]*tau
        pz = s[2] + s[5]*tau - 0.5*g*tau*tau
        vx = s[3]
        vy = s[4]
        vz = s[5] - g*tau
        return np.array([px,py,pz,vx,vy,vz], dtype=np.float64)

def compute_robot_center_from_tags(tag_info):
    t4 = tag_info.get('tag4', None)
    t5 = tag_info.get('tag5', None)
    shift_m = 0.096
    if t4 is not None and t5 is not None:
        p4 = np.asarray(t4.get('world_pos', t4.get('pos')), dtype=np.float64)
        p5 = np.asarray(t5.get('world_pos', t5.get('pos')), dtype=np.float64)
        center = 0.5*(p4 + p5)
        return center
    if t4 is not None:
        p4 = np.asarray(t4.get('world_pos', t4.get('pos')), dtype=np.float64)
        y_axis = np.asarray(t4.get('y_axis_unit', [0.0, 1.0, 0.0]), dtype=np.float64)
        center = p4 + (-shift_m) * y_axis
        return center
    if t5 is not None:
        p5 = np.asarray(t5.get('world_pos', t5.get('pos')), dtype=np.float64)
        y_axis = np.asarray(t5.get('y_axis_unit', [0.0, 1.0, 0.0]), dtype=np.float64)
        center = p5 + (shift_m) * y_axis
        return center
    return None

def append_prediction_log(predicted_pos, predicted_t, current_time, robot_pos, v_req=None, can_reach=None, measured_pos=None, meas_ts=None, ekf_state=None):
    entry = {
        "predicted_pos": [float(predicted_pos[0]), float(predicted_pos[1]), float(predicted_pos[2])],
        "predicted_t": float(predicted_t),
        "current_time": float(current_time),
        "robot_pos": (None if robot_pos is None else [float(robot_pos[0]), float(robot_pos[1]), float(robot_pos[2])]),
        "v_req": (None if v_req is None else float(v_req)),
        "can_reach_in_tau": bool(can_reach) if can_reach is not None else None,
        "measured_pos": (None if measured_pos is None else [float(measured_pos[0]), float(measured_pos[1]), float(measured_pos[2])]),
        "meas_ts": (None if meas_ts is None else float(meas_ts)),
        "ekf_state": (None if ekf_state is None else [float(x) for x in ekf_state])
    }
    try:
        with open(_PRED_LOG_PATH, "a", encoding="utf-8") as f:
            f.write(json.dumps(entry) + "\n")
    except Exception as e:
        print("[PRED_LOG_ERR]", e)

# ---------- Color masking helpers ----------
def hsv_mask_from_vals(bgr_img, hsvVals):
    hsv = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2HSV)
    lower = np.array([hsvVals['hmin'], hsvVals['smin'], hsvVals['vmin']], dtype=np.uint8)
    upper = np.array([hsvVals['hmax'], hsvVals['smax'], hsvVals['vmax']], dtype=np.uint8)
    mask = cv2.inRange(hsv, lower, upper)
    mask = cv2.medianBlur(mask, 5)
    return mask

def postprocess_mask(mask):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))
    m = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=1)
    m = cv2.morphologyEx(m, cv2.MORPH_CLOSE, kernel, iterations=1)
    return m

def find_candidate_contours(mask):
    if mask is None:
        return []
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    candidates = []
    for c in contours:
        area = cv2.contourArea(c)
        if area < MIN_AREA or area > MAX_AREA:
            continue
        perim = cv2.arcLength(c, True)
        if perim <= 0:
            continue
        circularity = 4 * np.pi * area / (perim * perim)
        x,y,w,h = cv2.boundingRect(c)
        aspect = float(w)/float(h) if h>0 else 0.0
        if circularity >= CIRCULARITY_MIN or (0.5*min(w,h) > 5 and area > (MIN_AREA*2)):
            if aspect <= ASPECT_RATIO_MAX:
                candidates.append((c, area, (int(x),int(y),int(w),int(h))))
    candidates.sort(key=lambda d: d[1], reverse=True)
    return candidates

def estimate_pose_apriltag(corners, tag_size, cam_mtx, cam_dist):
    half = tag_size / 2.0
    objp = np.array([
        [-half,  half, 0.0],
        [ half,  half, 0.0],
        [ half, -half, 0.0],
        [-half, -half, 0.0]
    ], dtype=np.float32)

    imgp = corners.reshape(4,2).astype(np.float32)

    ok, rvec, tvec = cv2.solvePnP(
        objp, imgp, cam_mtx, cam_dist,
        flags=cv2.SOLVEPNP_ITERATIVE
    )

    if not ok:
        raise RuntimeError("solvePnP failed")

    R, _ = cv2.Rodrigues(rvec)
    T = np.eye(4)
    T[:3, :3] = R
    T[:3, 3] = tvec.reshape(3)
    return T

# APRILTAG THREAD
class AprilTagThread(threading.Thread):
    def __init__(self, cam_name, frame_queue, detect_cache, lock, calibrator, shared_robot_poses):
        super().__init__(daemon=True)
        self.cam_name = cam_name
        self.frame_queue = frame_queue
        self.detect_cache = detect_cache
        self.lock = lock
        self.detector = create_april_detector()
        self.stop_flag = False
        self.calibrator = calibrator
        self.shared_robot_poses = shared_robot_poses

    def run(self):
        print(f"[{self.cam_name}] AprilTagThread started")
        while not self.stop_flag:
            try:
                frame,ts = self.frame_queue.get(timeout=0.1)
            except queue.Empty:
                continue
            try:
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                corners, ids, _ = self.detector.detectMarkers(gray)
                det={"corners":corners,"ids":ids,"ts":ts,"det_time":time.time()}

                with self.lock:
                    if self.cam_name not in self.detect_cache:
                        self.detect_cache[self.cam_name]={}
                    self.detect_cache[self.cam_name]["tags"]=det

                if ids is not None:
                    self.calibrator.add_detection(self.cam_name,ids,corners,ts)
                    self.calibrator.try_compute_extrinsic(self.cam_name)

                    if self.cam_name in self.calibrator.extrinsics:
                        try:
                            K, dist = self.calibrator.load_intrinsics(self.cam_name)
                            for i,idarr in enumerate(ids):
                                tid = int(idarr[0])
                                if tid in (4,5):
                                    corners_i = np.array(corners[i]).reshape(4,2)

                                    T_tag_cam = estimate_pose_apriltag(corners_i, TAG_SIZES[tid], K, dist)
                                    R_tag_cam = T_tag_cam[:3,:3]
                                    t_tag_cam = T_tag_cam[:3,3].reshape(3,)

                                    cam_corners = (R_tag_cam @ np.array([
                                        [-TAG_SIZES[tid]/2, TAG_SIZES[tid]/2, 0.0],
                                        [ TAG_SIZES[tid]/2, TAG_SIZES[tid]/2, 0.0],
                                        [ TAG_SIZES[tid]/2, -TAG_SIZES[tid]/2, 0.0],
                                        [-TAG_SIZES[tid]/2, -TAG_SIZES[tid]/2, 0.0]
                                    ], dtype=np.float64).T).T + t_tag_cam.reshape(1,3)

                                    tag_origin_world = self.calibrator.cam_to_world(self.cam_name, t_tag_cam)
                                    world_corners = self.calibrator.cam_to_world(self.cam_name, cam_corners)

                                    mean_corner_z = float(np.mean(world_corners[:,2]))
                                    corrected_tag_origin_world = tag_origin_world.copy()
                                    if mean_corner_z < 0:
                                        corrected_tag_origin_world[2] = abs(corrected_tag_origin_world[2])
                                        print(f"[WARN] {self.cam_name} tag{tid} mean_corner_z negative ({mean_corner_z:.4f}). Flipping Z to {corrected_tag_origin_world[2]:.4f}")

                                    nominal_tag_height = TAG_MOUNT_HEIGHT
                                    if abs(corrected_tag_origin_world[2] - nominal_tag_height) > 0.05:
                                        print(f"[INFO] {self.cam_name} tag{tid} measured z {corrected_tag_origin_world[2]:.3f}, nominal {nominal_tag_height:.3f}")

                                    try:
                                        c0 = world_corners[0]; c1 = world_corners[1]; c3 = world_corners[3]
                                        local_x = c1 - c0
                                        local_minus_y = c3 - c0
                                        local_y = -local_minus_y
                                        y_axis_unit = local_y / (np.linalg.norm(local_y) + 1e-12)
                                    except Exception:
                                        y_axis_unit = np.array([0.0, 1.0, 0.0], dtype=np.float64)

                                    with self.lock:
                                        self.shared_robot_poses[tid] = {
                                            'world_pos': corrected_tag_origin_world,
                                            'cam': self.cam_name,
                                            'ts': ts,
                                            'det_time': time.time(),
                                            'reproj_src': 'estimate_pose_apriltag',
                                            'mean_corner_z': mean_corner_z,
                                            'cam_t': t_tag_cam.copy(),
                                            'y_axis_unit': y_axis_unit
                                        }
                                        # debug
                                        # print(f"tid: {tid}, pos: {corrected_tag_origin_world}")
                        except Exception as e:
                            print(f"[{self.cam_name}] robot pose compute error:", e)
                            traceback.print_exc()

            except Exception as e:
                print(f"[ERROR-{self.cam_name}] AprilTag Detection exception:", e)
                traceback.print_exc()

        print(f"[DETECT-{self.cam_name}] AprilTag Detector thread stopped")

    def stop(self):
        self.stop_flag = True

# BALL DETECTOR THREAD
class BallThread(threading.Thread):
    def __init__(self, cam_name, frame_queue, detect_cache, lock, shared_camera_candidates):
        super().__init__(daemon=True)
        self.cam_name = cam_name
        self.frame_queue = frame_queue
        self.detect_cache = detect_cache
        self.lock = lock
        self.stop_flag = False
        self.shared_camera_candidates = shared_camera_candidates

    def run(self):
        print(f"[{self.cam_name}] BallThread started")
        while not self.stop_flag:
            try:
                frame,ts=self.frame_queue.get(timeout=0.1)
            except queue.Empty:
                continue
            try:
                mo=hsv_mask_from_vals(frame,orange_hsvVals)
                mp=hsv_mask_from_vals(frame,purple_hsvVals)

                mc = cv2.bitwise_or(mo,mp)
                mc = postprocess_mask(mc)

                cand = find_candidate_contours(mc)

                dets = []
                for c,area,(x,y,w,h) in cand[:MAX_DETECTIONS_PER_CAM]:
                    M = cv2.moments(c)
                    if M["m00"] != 0:
                        cx = int(M["m10"]/M["m00"]); cy = int(M["m01"]/M["m00"])
                    else:
                        cx = x + w//2; cy = y + h//2

                    s_or = int(np.count_nonzero(mo[y:y+h,x:x+w])) if mo is not None else 0
                    s_pu = int(np.count_nonzero(mp[y:y+h,x:x+w])) if mp is not None else 0

                    if s_or>s_pu and s_or>0:
                        col="orange"
                    elif s_pu>s_or and s_pu>0:
                        col="purple"
                    else:
                        hsv_roi=cv2.cvtColor(frame[y:y+h,x:x+w],cv2.COLOR_BGR2HSV)
                        mean_h=int(np.mean(hsv_roi[:,:,0]))
                        if orange_hsvVals["hmin"]<=mean_h<=orange_hsvVals["hmax"]:
                            col="orange"
                        elif purple_hsvVals["hmin"]<=mean_h<=purple_hsvVals["hmax"]:
                            col="purple"
                        else:
                            col="unknown"

                    dets.append({
                        "bbox":(x,y,w,h),
                        "centroid":(cx,cy),
                        "area":float(area),
                        "color":col,
                        "ts":ts,
                        "det_time":time.time()
                    })
                with self.lock:
                    if self.cam_name not in self.detect_cache:
                        self.detect_cache[self.cam_name]={}
                    self.detect_cache[self.cam_name]["balls"] = dets
                    self.shared_camera_candidates[self.cam_name] = [{"centroid":d["centroid"], "area":d["area"], "color":d["color"], "ts":d["ts"]} for d in dets]
            except Exception as e:
                print(f"[ERROR-{self.cam_name}] ball detection exception:", e)
                traceback.print_exc()

        print(f"[{self.cam_name}] BallDetectorThread stopped")

    def stop(self):
        self.stop_flag = True

# Calibrator Class (same as before)
class StaticCalibrator:
    def __init__(self, tag_world_map, tag_size_map):
        self.tag_world_map = tag_world_map
        self.tag_size_map = tag_size_map
        self.obs = defaultdict(list)
        self.extrinsics = {}
        self.frame_count = defaultdict(int)
        self.P_cache = {}
        self.K_cache = {}
        self.dist_cache = {}

    def load_intrinsics(self, cam_name):
        if cam_name in self.K_cache:
            return self.K_cache[cam_name], self.dist_cache[cam_name]
        camera_matrix, dist_coeffs = load_camera_calib(cam_name)
        self.K_cache[cam_name] = camera_matrix
        self.dist_cache[cam_name] = dist_coeffs
        return camera_matrix, dist_coeffs

    def add_detection(self, cam_name, ids, corners, ts):
        if ids is None:
            return
        self.frame_count[cam_name] += 1
        for i, idarr in enumerate(ids):
            tid = int(idarr[0])
            if tid in STATIC_TAG_IDS:
                c = np.array(corners[i]).reshape(4,2).astype(np.float64)
                self.obs[cam_name].append((tid, c, ts))

    def try_compute_extrinsic(self, cam_name):
        if cam_name in self.extrinsics:
            return True

        if self.frame_count.get(cam_name, 0) < CALIB_FRAMES:
            return False

        if cam_name == "kreo1":
            target_tag = 2
        elif cam_name == "kreo2":
            target_tag = 1
        else:
            return False

        obs_list = list(reversed(self.obs.get(cam_name, [])))

        use_corners = None
        for (tid, corners, ts) in obs_list:
            if int(tid) == int(target_tag):
                use_corners = corners.reshape(4,2).astype(np.float64)
                break

        if use_corners is None:
            return False

        try:
            K, dist = self.load_intrinsics(cam_name)
        except Exception as e:
            return False

        obj_corners = np.array(self.tag_world_map[target_tag], dtype=np.float64)

        ok, rvec, tvec = cv2.solvePnP(
            obj_corners,
            use_corners,
            K, dist,
            flags=cv2.SOLVEPNP_ITERATIVE
        )

        if not ok:
            return False

        R, _ = cv2.Rodrigues(rvec)
        tvec = tvec.reshape(3,1)

        self.extrinsics[cam_name] = {
            "rvec": rvec,
            "tvec": tvec,
            "R": R
        }

        P = K @ np.hstack((R, tvec))
        self.P_cache[cam_name] = P

        print(f"[Calib] extrinsics computed for {cam_name}: tvec={tvec.ravel()}")

        return True

    def cam_to_world(self, cam_name, X_cam):
        e = self.extrinsics.get(cam_name)
        if e is None:
            raise RuntimeError("Calibrator: extrinsic not ready for " + cam_name)
        R = e['R']; t = e['tvec']
        X = np.asarray(X_cam, dtype=np.float64)
        if X.ndim == 1 and X.shape[0] == 3:
            Xc = X.reshape(3,1)
            Xw = R.T @ (Xc - t)
            return Xw[:,0]
        if X.ndim == 2 and X.shape[1] == 3:
            Xc = X.T
            Xw = R.T @ (Xc - t)
            return Xw.T
        if X.ndim == 2 and X.shape[0] == 3:
            Xc = X
            Xw = R.T @ (Xc - t)
            return Xw.T
        raise ValueError("Invalid X_cam shape: " + str(X.shape))

    def projection_matrix(self, cam_name):
        return self.P_cache.get(cam_name, None)

# Triangulation and reprojection helpers (same as before)
def undistort_points_to_normalized(K, dist, pts):
    if len(pts) == 0:
        return np.zeros((0,2), dtype=np.float64)
    pts = np.array(pts, dtype=np.float64).reshape(-1,1,2)
    und = cv2.undistortPoints(pts, K, dist, P=K)
    und = und.reshape(-1,2)
    return und

def triangulate_pair(P1, P2, pt1, pt2):
    pts1 = np.array(pt1, dtype=np.float64).reshape(2,1)
    pts2 = np.array(pt2, dtype=np.float64).reshape(2,1)
    Xh = cv2.triangulatePoints(P1, P2, pts1, pts2)
    X = (Xh[:3,0] / Xh[3,0]).astype(np.float64)
    return X

def reprojection_error(P, X_world, observed_xy):
    Xh = np.zeros((4,1), dtype=np.float64)
    Xh[:3,0] = X_world
    Xh[3,0] = 1.0
    proj = P @ Xh
    proj_xy = proj[:2,0] / proj[2,0]
    return float(np.linalg.norm(proj_xy - np.array(observed_xy, dtype=np.float64)))

def match_and_triangulate(camera_candidates, calibrator, max_pairs=128, reproj_thresh_px=6.0, depth_min=0.03, depth_max=10.0):
    cams = list(camera_candidates.keys())
    if len(cams) < 2:
        return []

    pair = None
    if 'kreo1' in camera_candidates and 'kreo2' in camera_candidates:
        pair = ('kreo1', 'kreo2')
    else:
        pair = (cams[0], cams[1])

    c1, c2 = pair
    cand1 = sorted(camera_candidates[c1], key=lambda x: -x.get('area',1))[:8]
    cand2 = sorted(camera_candidates[c2], key=lambda x: -x.get('area',1))[:8]
    P1 = calibrator.projection_matrix(c1)
    P2 = calibrator.projection_matrix(c2)
    if P1 is None or P2 is None:
        return []

    results = []
    for a in cand1:
        for b in cand2:
            if len(results) >= max_pairs:
                break
            x1 = a['centroid']
            x2 = b['centroid']
            try:
                Xw = triangulate_pair(P1, P2, x1, x2)
            except Exception:
                continue
            e1 = calibrator.extrinsics[c1]
            R1, t1 = e1['R'], e1['tvec']
            Xcam1 = R1 @ Xw.reshape(3,1) + t1
            depth1 = float(Xcam1[2,0])
            e2 = calibrator.extrinsics[c2]
            R2, t2 = e2['R'], e2['tvec']
            Xcam2 = R2 @ Xw.reshape(3,1) + t2
            depth2 = float(Xcam2[2,0])
            if not (depth_min < depth1 < depth_max and depth_min < depth2 < depth_max):
                continue
            err1 = reprojection_error(P1, Xw, x1)
            err2 = reprojection_error(P2, Xw, x2)
            tot = err1 + err2
            if tot > (2*reproj_thresh_px):
                continue
            results.append({'pt': Xw, 'reproj_err': tot, 'pair': (c1,c2), 'cam_pixels': (x1,x2), 'depths':(depth1,depth2), 'meas_ts': a.get('ts', time.time())})
    results = sorted(results, key=lambda r: r['reproj_err'])
    return results

# ---------- ZMQ subscriber ----------
ctx = zmq.Context()
sub = ctx.socket(zmq.SUB)
sub.connect(ZMQ_ADDR)
sub.setsockopt(zmq.RCVHWM, 1)
sub.setsockopt(zmq.CONFLATE, 1)
sub.setsockopt(zmq.LINGER, 0)

flushed = 0
while True:
    try:
        sub.recv_multipart(flags=zmq.NOBLOCK)
        flushed += 1
    except zmq.Again:
        break
if flushed > 0:
    print(f"[Subscriber] Flushed {flushed} stale messages.")
for t in SUB_TOPICS:
    sub.setsockopt(zmq.SUBSCRIBE, t)

frames = {}
fps_windows = defaultdict(lambda: deque())
frame_queues = {t.decode(): queue.Queue(maxsize=1) for t in SUB_TOPICS}
detect_cache = {}
detect_lock = threading.Lock()
tag_threads={}
ball_threads={}

calibrator = StaticCalibrator(TAG_WORLD_MAP, TAG_SIZES)
shared_camera_candidates = defaultdict(list)
shared_robot_poses = {}
last_triangulated_ball = None

# EKF instance (tuned)
ball_ekf = BallEKF(pos_sigma=0.02, vel_sigma=1.0, accel_sigma=7.0)

for t in SUB_TOPICS:
    cam_name = t.decode()
    tag_threads[cam_name] = AprilTagThread(cam_name,frame_queues[cam_name],detect_cache,detect_lock,calibrator,shared_robot_poses)
    ball_threads[cam_name] = BallThread(cam_name,frame_queues[cam_name],detect_cache,detect_lock,shared_camera_candidates)
    tag_threads[cam_name].start()
    ball_threads[cam_name].start()

print("[Subscriber] connected, waiting for frames... (Press ESC to exit)")

last_show = time.time()

try:
    while True:
        parts=recv_latest(sub)
        if parts is None: continue

        topic=parts[0]; cam=topic.decode()
        if len(parts)>=3:
            ts_part=parts[1]; jpg_part=parts[2]
        else:
            ts_part=None; jpg_part=parts[1]

        recv_t=time.time()
        try: cam_ts=float(ts_part.decode()) if ts_part else recv_t
        except: cam_ts=recv_t

        img=cv2.imdecode(np.frombuffer(jpg_part,np.uint8),cv2.IMREAD_COLOR)
        if img is None: continue

        fps=update_fps(cam,cam_ts)
        frames[cam]={"img":img,"cam_ts":cam_ts,"fps":fps}

        fq=frame_queues[cam]
        try: fq.get_nowait()
        except: pass
        try: fq.put_nowait((img.copy(),cam_ts))
        except: pass

        with detect_lock:
            ready = all(c in calibrator.extrinsics for c in [t.decode() for t in SUB_TOPICS])
        if ready:
            with detect_lock:
                tri_results = match_and_triangulate(shared_camera_candidates, calibrator)
            if len(tri_results) > 0:
                best = tri_results[0]
                Xw = best['pt']
                last_triangulated_ball = {'pos': Xw, 'err': best['reproj_err'], 'ts': time.time(), 'pair': best['pair'], 'depths':best['depths']}

                meas_ts = best.get('meas_ts', time.time())
                reproj = best.get('reproj_err', None)
                # new measurement noise mapping (tighter)
                if reproj is not None:
                    sigma = max(0.015, 0.002 * float(reproj))
                    meas_R = np.diag([sigma*sigma, sigma*sigma, sigma*sigma])
                else:
                    meas_R = None

                # EKF update (with internal velocity reset if measurement jumps)
                updated = ball_ekf.update(Xw, meas_R=meas_R, meas_ts=meas_ts)

                # prediction horizon reduced to 15 ms
                tau = 0.015
                pred = ball_ekf.predict_future(tau)
                if pred is not None:
                    p_future = pred[0:3]
                    pred_abs_t = (ball_ekf.last_ts if ball_ekf.last_ts is not None else time.time()) + tau

                    # compute robot center from tag4/tag5
                    tag_info = {}
                    if 4 in shared_robot_poses:
                        tag_info['tag4'] = shared_robot_poses[4]
                    if 5 in shared_robot_poses:
                        tag_info['tag5'] = shared_robot_poses[5]

                    robot_center = compute_robot_center_from_tags(tag_info)
                    if robot_center is None:
                        for k,v in shared_robot_poses.items():
                            if isinstance(v, dict) and 'world_pos' in v:
                                robot_center = np.asarray(v['world_pos'], dtype=np.float64)
                                break

                    v_req = None
                    can_reach = None
                    if robot_center is not None:
                        dist = float(np.linalg.norm(p_future - robot_center))
                        v_req = dist / tau if tau > 0 else float('inf')
                        can_reach = (v_req <= robot_max_speed)

                    # log measured_pos, meas_ts, ekf_state
                    ekf_state = None
                    if ball_ekf.x is not None:
                        ekf_state = ball_ekf.x.copy().tolist()

                    append_prediction_log(predicted_pos=p_future, predicted_t=pred_abs_t,
                                          current_time=time.time(), robot_pos=robot_center,
                                          v_req=v_req, can_reach=can_reach,
                                          measured_pos=Xw, meas_ts=meas_ts, ekf_state=ekf_state)

                    try:
                        with detect_lock:
                            shared_robot_poses['ball_prediction'] = {
                                'pred_pos': p_future.tolist(),
                                'pred_t': pred_abs_t,
                                'meas_ts': meas_ts,
                                'v_req': v_req,
                                'can_reach_in_tau': can_reach
                            }
                    except Exception:
                        shared_robot_poses['ball_prediction'] = {
                            'pred_pos': p_future.tolist(),
                            'pred_t': pred_abs_t,
                            'meas_ts': meas_ts,
                            'v_req': v_req,
                            'can_reach_in_tau': can_reach
                        }

                    print(f"[EKF PRED] t+{tau:.3f}s -> {p_future}  can_reach={can_reach} v_req={v_req} meas_z={Xw[2]:.3f} ekf_z={ball_ekf.x[2]:.3f}")
                else:
                    print("[EKF] prediction not ready (filter uninitialized)")

        # visualization / CLI output (same structure as before)
        if all(k in frames for k in [t.decode() for t in SUB_TOPICS]):
            cams=[t.decode() for t in SUB_TOPICS]
            L=frames[cams[0]]; R=frames[cams[1]]
            drift_ms=abs(L["cam_ts"]-R["cam_ts"])*1000.0

            def overlay(F,cam_name):
                im=F["img"].copy()
                y=20
                cv2.putText(im,f"{cam_name}",(10,y),cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,32,20),2)
                cv2.putText(im,f"FPS:{F['fps']:.1f}",(10,y+26),cv2.FONT_HERSHEY_SIMPLEX,0.6,(14,117,5),2)
                cv2.putText(im,f"cam_ts:{fmt_ts(F['cam_ts'])}",(10,y+52),cv2.FONT_HERSHEY_SIMPLEX,0.5,(5,12,117),1)

                with detect_lock:
                    block=detect_cache.get(cam_name,{})

                    if "tags" in block and block["tags"]["ids"] is not None:
                        cs=block["tags"]["corners"]
                        ids=block["tags"]["ids"]
                        cv2.aruco.drawDetectedMarkers(im,cs,ids)

                    if "balls" in block:
                        for i,d in enumerate(block["balls"]):
                            x,y,w,h=d["bbox"]
                            cx,cy=d["centroid"]
                            color=d["color"]
                            if color=="orange": bc=(0,200,255)
                            elif color=="purple": bc=(200,0,200)
                            else: bc=(0,200,200)
                            cv2.rectangle(im,(x,y),(x+w,y+h),bc,2)
                            cv2.circle(im,(cx,cy),4,(0,0,255),-1)
                            cv2.putText(im,f"{color}:{i}",(x,y-6),
                                        cv2.FONT_HERSHEY_SIMPLEX,0.5,bc,2)

                    text_y = 80
                    if shared_robot_poses:
                        for tid,info in shared_robot_poses.items():
                            pos = info.get('world_pos')
                            if pos is not None and isinstance(pos, (list, tuple, np.ndarray)):
                                tx = f"Tag{tid} world: {pos[0]:.3f},{pos[1]:.3f},{pos[2]:.3f}"
                                cv2.putText(im, tx, (10, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,0), 1)
                                text_y += 18

                    if cam_name == cams[0] and last_triangulated_ball is not None:
                        p = last_triangulated_ball['pos']
                        tx = f"Ball world: {p[0]:.3f},{p[1]:.3f},{p[2]:.3f} err:{last_triangulated_ball['err']:.2f}"
                        cv2.putText(im, tx, (10, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,255), 1)

                return im

            if VISUALIZE and (time.time()-last_show)>(1.0/DISPLAY_FPS):
                last_show=time.time()
                left_im=overlay(L,cams[0])
                right_im=overlay(R,cams[1])

                h=max(left_im.shape[0],right_im.shape[0])
                right_res=cv2.resize(right_im,(left_im.shape[1],h))
                tile=np.hstack([left_im,right_res])

                cv2.putText(tile,f"Drift:{drift_ms:.1f}ms",(10,20),
                            cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,0,255),2)

                cv2.putText(tile, f"Host now: {fmt_ts(time.time())}", (10, 44), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1)

                cv2.imshow("Combined Detection",tile)
            elif not VISUALIZE:
                with detect_lock:
                    tag_summary = []
                    parts_status = []
                    for c in cams:
                        block = detect_cache.get(c,{})
                        if "tags" in block and block["tags"]["ids"] is not None:
                            ids=block["tags"]["ids"]
                            tag_summary.append(f"{c}: {ids.flatten().tolist()}")
                        elif "tags" in block:
                            tag_summary.append(f"{c}: No tags")
                        else:
                            tag_summary.append(f"{c}: No detection data")
                        if "balls" in block:
                            counts = { "orange":0, "purple":0, "unknown":0 }
                            for i,d in enumerate(block["balls"]):
                                counts[d.get("color","unknown")] = counts.get(d.get("color","unknown"),0) + 1
                            parts_status.append(f"{c}: Orange: {counts['orange']} Purple: {counts['purple']}")
                        else:
                            parts_status.append(f"{c}:NoBall")
                status = (
                    f"Drift {drift_ms:.1f} ms | "
                    f"{cams[0]} ts: {fmt_ts(L['cam_ts'])} | "
                    f"{cams[1]} ts: {fmt_ts(R['cam_ts'])} | "
                    f"Host now: {fmt_ts(time.time())} | "
                    f"{cams[0]} FPS: {L['fps']:.1f} | "
                    f"{cams[1]} FPS: {R['fps']:.1f} | "
                    f"Tags:" + ",".join(tag_summary)
                )
                sys.stdout.write("\r" + status + " " * 20 + " | ".join(parts_status) + " " * 20)
                sys.stdout.flush()

        if cv2.waitKey(1)&0xFF==27:
            break

except KeyboardInterrupt:
    pass

finally:
    for t in tag_threads.values(): t.stop()
    for t in ball_threads.values(): t.stop()
    time.sleep(0.1)
    cv2.destroyAllWindows()
    sub.close()
    ctx.term()
    print("Exit clean.")
# Out:
# [kreo1] AprilTagThread started
# [kreo1] BallThread started
# [kreo2] AprilTagThread started
# [kreo2] BallThread started
# [Subscriber] connected, waiting for frames... (Press ESC to exit)
# [INFO] Loaded calibrated camera parameters
# [Calib] extrinsics computed for kreo2: tvec=[-0.34785924  0.66527878  2.27805231]
# [INFO] Loaded calibrated camera parameters
# [Calib] extrinsics computed for kreo1: tvec=[ 0.21496784 -0.16489263  2.78747444]
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0700). Flipping Z to 0.0700
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0825). Flipping Z to 0.0825
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0820). Flipping Z to 0.0820
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0679). Flipping Z to 0.0679
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0679). Flipping Z to 0.0679
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0705). Flipping Z to 0.0705
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0728). Flipping Z to 0.0728
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0784). Flipping Z to 0.0784
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0647). Flipping Z to 0.0647
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0938). Flipping Z to 0.0938
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0661). Flipping Z to 0.0661
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1100). Flipping Z to 0.1100
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0674). Flipping Z to 0.0674
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0753). Flipping Z to 0.0753
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0692). Flipping Z to 0.0692
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0766). Flipping Z to 0.0766
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0609). Flipping Z to 0.0609
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0717). Flipping Z to 0.0717
# [EKF PRED] t+0.015s -> [ 1.28102489 -0.0241749   0.81392083]  can_reach=False v_req=86.73962864745793 meas_z=0.815 ekf_z=0.815
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0667). Flipping Z to 0.0667
# [EKF PRED] t+0.015s -> [ 1.28102489 -0.0241749   0.81392083]  can_reach=False v_req=86.76851782050026 meas_z=0.815 ekf_z=0.815
# [EKF PRED] t+0.015s -> [ 1.28110055 -0.02745285  0.81129633]  can_reach=False v_req=86.73234836632383 meas_z=0.807 ekf_z=0.812
# [EKF PRED] t+0.015s -> [ 1.28051269 -0.03128081  0.79558138]  can_reach=False v_req=86.17964708997452 meas_z=0.803 ekf_z=0.803
# [EKF PRED] t+0.015s -> [ 1.28049983 -0.03136459  0.79569119]  can_reach=False v_req=86.18465785427848 meas_z=0.803 ekf_z=0.803
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0609). Flipping Z to 0.0609
# [EKF PRED] t+0.015s -> [ 1.28049541 -0.03139334  0.79572887]  can_reach=False v_req=86.25898277660042 meas_z=0.803 ekf_z=0.803
# [EKF PRED] t+0.015s -> [ 1.28055499 -0.03355402  0.78942759]  can_reach=False v_req=86.06623068545336 meas_z=0.798 ekf_z=0.796
# [EKF PRED] t+0.015s -> [ 1.27841305 -0.03114166  0.78918652]  can_reach=False v_req=85.90093757570725 meas_z=0.796 ekf_z=0.794
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0786). Flipping Z to 0.0786
# [EKF PRED] t+0.015s -> [ 1.27830588 -0.03089393  0.79030974]  can_reach=False v_req=85.83911117596197 meas_z=0.796 ekf_z=0.795
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0903). Flipping Z to 0.0903
# [EKF PRED] t+0.015s -> [ 1.27563358 -0.03047425  0.78925386]  can_reach=False v_req=85.30099869331121 meas_z=0.795 ekf_z=0.793
# [EKF PRED] t+0.015s -> [ 1.27552644 -0.03050396  0.79034011]  can_reach=False v_req=85.33588916635799 meas_z=0.795 ekf_z=0.794
# [EKF PRED] t+0.015s -> [ 1.27418375 -0.029511    0.79059625]  can_reach=False v_req=85.25619444152315 meas_z=0.795 ekf_z=0.794
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0626). Flipping Z to 0.0626
# [EKF PRED] t+0.015s -> [ 1.27348487 -0.02899416  0.79072958]  can_reach=False v_req=85.43548018175531 meas_z=0.795 ekf_z=0.794
# [EKF PRED] t+0.015s -> [ 1.26555638 -0.02825944  0.78749772]  can_reach=False v_req=84.89025802160982 meas_z=0.793 ekf_z=0.792
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0674). Flipping Z to 0.0674
# [EKF PRED] t+0.015s -> [ 1.26555372 -0.02830174  0.78807304]  can_reach=False v_req=84.8511021083464 meas_z=0.793 ekf_z=0.792
# [EKF PRED] t+0.015s -> [ 1.26555281 -0.02831615  0.7882691 ]  can_reach=False v_req=84.85861947963802 meas_z=0.793 ekf_z=0.793
# [EKF PRED] t+0.015s -> [ 1.2383295  -0.01428241  0.80119319]  can_reach=False v_req=83.67601998215375 meas_z=0.804 ekf_z=0.802
# [EKF PRED] t+0.015s -> [ 1.23808462 -0.01411107  0.80192903]  can_reach=False v_req=83.68850588656288 meas_z=0.804 ekf_z=0.803
# [EKF PRED] t+0.015s -> [ 1.23664674 -0.01128714  0.8034655 ]  can_reach=False v_req=83.62089850450496 meas_z=0.807 ekf_z=0.804
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1210). Flipping Z to 0.1210
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0813). Flipping Z to 0.0813
# [EKF PRED] t+0.015s -> [ 1.22576571 -0.01805639  0.80824647]  can_reach=False v_req=82.73369584971773 meas_z=0.811 ekf_z=0.811
# [EKF PRED] t+0.015s -> [ 1.22600418 -0.0184222   0.80871759]  can_reach=False v_req=82.77061080044696 meas_z=0.811 ekf_z=0.811
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0681). Flipping Z to 0.0681
# [EKF PRED] t+0.015s -> [ 1.22346016 -0.0111703   0.81295958]  can_reach=False v_req=83.42095663930085 meas_z=0.821 ekf_z=0.814
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0626). Flipping Z to 0.0626
# [EKF PRED] t+0.015s -> [ 1.22217707 -0.00751276  0.81509906]  can_reach=False v_req=83.62967442657624 meas_z=0.821 ekf_z=0.816
# [EKF PRED] t+0.015s -> [ 1.20611237 -0.01078038  0.82690092]  can_reach=False v_req=83.36032480720651 meas_z=0.829 ekf_z=0.828
# [EKF PRED] t+0.015s -> [ 1.20611354 -0.01091229  0.82749354]  can_reach=False v_req=83.38685078484573 meas_z=0.829 ekf_z=0.828
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0647). Flipping Z to 0.0647
# [EKF PRED] t+0.015s -> [ 1.20444462 -0.0042668   0.83181164]  can_reach=False v_req=83.40038211760086 meas_z=0.838 ekf_z=0.832
# [EKF PRED] t+0.015s -> [ 1.20360338e+00 -9.17041541e-04  8.33988249e-01]  can_reach=False v_req=83.38837560649951 meas_z=0.838 ekf_z=0.833
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0811). Flipping Z to 0.0811
# [EKF PRED] t+0.015s -> [ 1.19471631 -0.00290838  0.84280014]  can_reach=False v_req=83.08893464694432 meas_z=0.845 ekf_z=0.844
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0711). Flipping Z to 0.0711
# [EKF PRED] t+0.015s -> [ 1.19487281 -0.00305831  0.84326997]  can_reach=False v_req=82.99985009075913 meas_z=0.845 ekf_z=0.844
# [EKF PRED] t+0.015s -> [ 1.19492627 -0.00310953  0.84343047]  can_reach=False v_req=83.00999675361534 meas_z=0.845 ekf_z=0.844
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0651). Flipping Z to 0.0651
# [EKF PRED] t+0.015s -> [ 1.19115305 -0.00901174  0.84330178]  can_reach=False v_req=82.92483202159198 meas_z=0.849 ekf_z=0.849
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0831). Flipping Z to 0.0831
# [EKF PRED] t+0.015s -> [ 1.19121009 -0.00902599  0.84358199]  can_reach=False v_req=82.99643811462148 meas_z=0.849 ekf_z=0.849
# [EKF PRED] t+0.015s -> [ 1.19122922 -0.00903077  0.84367595]  can_reach=False v_req=83.00133755431762 meas_z=0.849 ekf_z=0.849
# [EKF PRED] t+0.015s -> [1.18682193 0.00872023 0.85765232]  can_reach=False v_req=83.05549830420168 meas_z=0.860 ekf_z=0.859
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1169). Flipping Z to 0.1169
# [EKF PRED] t+0.015s -> [1.18678005 0.00902223 0.85842234]  can_reach=False v_req=82.59576000879824 meas_z=0.860 ekf_z=0.859
# [EKF PRED] t+0.015s -> [1.18676582 0.00912481 0.85868387]  can_reach=False v_req=82.60415710707909 meas_z=0.860 ekf_z=0.859
# [EKF PRED] t+0.015s -> [1.1883971  0.00370032 0.85570758]  can_reach=False v_req=82.65306549223746 meas_z=0.861 ekf_z=0.860
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0679). Flipping Z to 0.0679
# [EKF PRED] t+0.015s -> [1.18848826 0.00336276 0.8560429 ]  can_reach=False v_req=83.40604639826547 meas_z=0.861 ekf_z=0.860
# [EKF PRED] t+0.015s -> [1.18851925 0.00324798 0.85615693]  can_reach=False v_req=83.41435977249209 meas_z=0.861 ekf_z=0.860
# [EKF PRED] t+0.015s -> [1.18937352 0.00450899 0.85558331]  can_reach=False v_req=83.40981186975658 meas_z=0.861 ekf_z=0.860
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0677). Flipping Z to 0.0677
# [EKF PRED] t+0.015s -> [1.18936534 0.0045959  0.85617358]  can_reach=False v_req=83.39046931664336 meas_z=0.861 ekf_z=0.860
# [EKF PRED] t+0.015s -> [1.18936257 0.00462545 0.85637425]  can_reach=False v_req=83.3982500530139 meas_z=0.861 ekf_z=0.860
# [EKF PRED] t+0.015s -> [ 1.18836982 -0.00166401  0.85166913]  can_reach=False v_req=83.26363718289049 meas_z=0.857 ekf_z=0.857
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0646). Flipping Z to 0.0646
# [EKF PRED] t+0.015s -> [ 1.18833401 -0.00181024  0.85222161]  can_reach=False v_req=83.33809546217162 meas_z=0.857 ekf_z=0.857
# [EKF PRED] t+0.015s -> [ 1.18832175 -0.00186031  0.8524108 ]  can_reach=False v_req=83.34631871615296 meas_z=0.857 ekf_z=0.857
# [EKF PRED] t+0.015s -> [ 1.18843476e+00 -1.04005271e-03  8.51985952e-01]  can_reach=False v_req=83.31945671730037 meas_z=0.857 ekf_z=0.856
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0820). Flipping Z to 0.0820
# [EKF PRED] t+0.015s -> [ 1.18741246 -0.00606238  0.84569637]  can_reach=False v_req=82.86860441715362 meas_z=0.852 ekf_z=0.851
# [EKF PRED] t+0.015s -> [ 1.18736816 -0.00627487  0.84618456]  can_reach=False v_req=82.89044972341368 meas_z=0.852 ekf_z=0.852
# [EKF PRED] t+0.015s -> [ 1.18735245 -0.00635026  0.84635776]  can_reach=False v_req=82.89820261503213 meas_z=0.852 ekf_z=0.852
# [EKF PRED] t+0.015s -> [ 1.1873444  -0.00638887  0.84644647]  can_reach=False v_req=82.9021738780761 meas_z=0.852 ekf_z=0.852
# [EKF PRED] t+0.015s -> [ 1.18538529 -0.0068429   0.84060069]  can_reach=False v_req=82.57221763521049 meas_z=0.847 ekf_z=0.846
# [EKF PRED] t+0.015s -> [ 1.18562149 -0.0065784   0.84121299]  can_reach=False v_req=82.6043758581641 meas_z=0.847 ekf_z=0.845
# [EKF PRED] t+0.015s -> [ 1.18569101 -0.00654502  0.84227371]  can_reach=False v_req=82.65103745740562 meas_z=0.847 ekf_z=0.846
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0589). Flipping Z to 0.0589
# [EKF PRED] t+0.015s -> [ 1.18648816 -0.00509521  0.84044698]  can_reach=False v_req=82.67377986165904 meas_z=0.846 ekf_z=0.844
# [EKF PRED] t+0.015s -> [ 1.18598214 -0.0040322   0.8394481 ]  can_reach=False v_req=82.58874613408427 meas_z=0.845 ekf_z=0.844
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0725). Flipping Z to 0.0725
# [EKF PRED] t+0.015s -> [ 1.18508663 -0.01314862  0.83275112]  can_reach=False v_req=82.59014313298978 meas_z=0.834 ekf_z=0.839
# [EKF PRED] t+0.015s -> [ 1.18506412 -0.01965686  0.82444414]  can_reach=False v_req=82.3682040074353 meas_z=0.833 ekf_z=0.832
# [EKF PRED] t+0.015s -> [ 1.18511518 -0.0198838   0.82517906]  can_reach=False v_req=82.40506405403782 meas_z=0.833 ekf_z=0.832
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0684). Flipping Z to 0.0684
# [EKF PRED] t+0.015s -> [ 1.1851343  -0.01996876  0.82545417]  can_reach=False v_req=82.28035891260092 meas_z=0.833 ekf_z=0.832
# [EKF PRED] t+0.015s -> [ 1.1851443  -0.02001322  0.82559817]  can_reach=False v_req=82.28756878077516 meas_z=0.833 ekf_z=0.832
# [EKF PRED] t+0.015s -> [ 1.18280547 -0.02425063  0.81988328]  can_reach=False v_req=82.02096638890646 meas_z=0.826 ekf_z=0.825
# [EKF PRED] t+0.015s -> [ 1.18277116 -0.02409386  0.82066416]  can_reach=False v_req=82.04797942311687 meas_z=0.826 ekf_z=0.826
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0672). Flipping Z to 0.0672
# [EKF PRED] t+0.015s -> [ 1.18704685 -0.01965856  0.81808823]  can_reach=False v_req=82.09025006784728 meas_z=0.824 ekf_z=0.823
# [EKF PRED] t+0.015s -> [ 1.18698902 -0.0195133   0.81865258]  can_reach=False v_req=82.10750643364604 meas_z=0.824 ekf_z=0.823
# [EKF PRED] t+0.015s -> [ 1.18683281 -0.01964291  0.81965187]  can_reach=False v_req=82.14277132918717 meas_z=0.824 ekf_z=0.823
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0796). Flipping Z to 0.0796
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0695). Flipping Z to 0.0695
# [EKF PRED] t+0.015s -> [ 1.18686959 -0.02502711  0.81076779]  can_reach=False v_req=81.77301440804835 meas_z=0.818 ekf_z=0.817
# [EKF PRED] t+0.015s -> [ 1.18681176 -0.02545825  0.81114614]  can_reach=False v_req=81.75934784422864 meas_z=0.818 ekf_z=0.817
# [EKF PRED] t+0.015s -> [ 1.1867907  -0.02561531  0.81128398]  can_reach=False v_req=81.76685139604197 meas_z=0.818 ekf_z=0.817
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0857). Flipping Z to 0.0857
# [EKF PRED] t+0.015s -> [ 1.18677979 -0.02569661  0.81135533]  can_reach=False v_req=81.67059489562969 meas_z=0.818 ekf_z=0.817
# [EKF PRED] t+0.015s -> [ 1.18657048 -0.02560922  0.81137511]  can_reach=False v_req=81.65928053666521 meas_z=0.818 ekf_z=0.818
# [EKF PRED] t+0.015s -> [ 1.18288185 -0.02489701  0.81404838]  can_reach=False v_req=81.56924879437446 meas_z=0.819 ekf_z=0.818
# [EKF PRED] t+0.015s -> [ 1.18285665 -0.02482275  0.81459302]  can_reach=False v_req=81.58842674506094 meas_z=0.819 ekf_z=0.818
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0840). Flipping Z to 0.0840
# [EKF PRED] t+0.015s -> [ 1.18248461 -0.02224485  0.81650524]  can_reach=False v_req=81.6423646230239 meas_z=0.823 ekf_z=0.820
# [EKF PRED] t+0.015s -> [ 1.17625331 -0.02414408  0.82420178]  can_reach=False v_req=81.68247196117568 meas_z=0.827 ekf_z=0.827
# [EKF PRED] t+0.015s -> [ 1.17621695 -0.02420487  0.82474795]  can_reach=False v_req=81.70406837062276 meas_z=0.827 ekf_z=0.827
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0710). Flipping Z to 0.0710
# [EKF PRED] t+0.015s -> [ 1.17620464 -0.02422545  0.82493288]  can_reach=False v_req=81.69526149428442 meas_z=0.827 ekf_z=0.827
# [EKF PRED] t+0.015s -> [ 1.17619844 -0.0242358   0.82502589]  can_reach=False v_req=81.69893848517141 meas_z=0.827 ekf_z=0.827
# [EKF PRED] t+0.015s -> [ 1.17559949 -0.0205498   0.82751695]  can_reach=False v_req=81.7003859874035 meas_z=0.837 ekf_z=0.829
# [EKF PRED] t+0.015s -> [ 1.16902621 -0.01395208  0.84100226]  can_reach=False v_req=81.80904129124919 meas_z=0.842 ekf_z=0.841
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0684). Flipping Z to 0.0684
# [EKF PRED] t+0.015s -> [ 1.16627027 -0.01827437  0.84161839]  can_reach=False v_req=81.8180824813854 meas_z=0.845 ekf_z=0.844
# [EKF PRED] t+0.015s -> [ 1.16631867 -0.0187      0.84207285]  can_reach=False v_req=81.84735206502125 meas_z=0.845 ekf_z=0.844
# [EKF PRED] t+0.015s -> [ 1.1664522  -0.0142461   0.84575442]  can_reach=False v_req=81.92385928010029 meas_z=0.852 ekf_z=0.847
# [EKF PRED] t+0.015s -> [ 1.16378874 -0.01228618  0.85493018]  can_reach=False v_req=82.14351011367386 meas_z=0.856 ekf_z=0.855
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1028). Flipping Z to 0.1028
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0726). Flipping Z to 0.0726
# [EKF PRED] t+0.015s -> [ 1.15995756 -0.01723278  0.85774861]  can_reach=False v_req=81.792275284256 meas_z=0.860 ekf_z=0.859
# [EKF PRED] t+0.015s -> [ 1.15974979 -0.01781209  0.85839605]  can_reach=False v_req=81.82008248832211 meas_z=0.860 ekf_z=0.859
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0702). Flipping Z to 0.0702
# [EKF PRED] t+0.015s -> [ 1.16000748 -0.01143728  0.86370552]  can_reach=False v_req=82.47315591087292 meas_z=0.870 ekf_z=0.863
# [EKF PRED] t+0.015s -> [ 1.16014285 -0.00808825  0.86649487]  can_reach=False v_req=82.53685957100116 meas_z=0.870 ekf_z=0.864
# [EKF PRED] t+0.015s -> [ 1.15907753 -0.00816042  0.87288575]  can_reach=False v_req=82.76184477459813 meas_z=0.875 ekf_z=0.875
# [EKF PRED] t+0.015s -> [ 1.15918478 -0.00828594  0.87323379]  can_reach=False v_req=82.78422397247172 meas_z=0.875 ekf_z=0.875
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0711). Flipping Z to 0.0711
# [EKF PRED] t+0.015s -> [ 1.15940613 -0.00657286  0.87474645]  can_reach=False v_req=82.81636612116404 meas_z=0.879 ekf_z=0.876
# [EKF PRED] t+0.015s -> [ 1.15951777 -0.00570878  0.87550943]  can_reach=False v_req=82.8388175146343 meas_z=0.879 ekf_z=0.877
# [EKF PRED] t+0.015s -> [ 1.15931428 -0.00791652  0.87619181]  can_reach=False v_req=82.8988497673013 meas_z=0.882 ekf_z=0.881
# [EKF PRED] t+0.015s -> [ 1.15982161 -0.00741801  0.87719401]  can_reach=False v_req=82.95703480921699 meas_z=0.883 ekf_z=0.882
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1046). Flipping Z to 0.1046
# [EKF PRED] t+0.015s -> [ 1.15999199 -0.00725058  0.87753059]  can_reach=False v_req=82.45075421577032 meas_z=0.883 ekf_z=0.882
# [EKF PRED] t+0.015s -> [ 1.16007742 -0.00716664  0.87769935]  can_reach=False v_req=82.46054598327399 meas_z=0.883 ekf_z=0.882
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0563). Flipping Z to 0.0563
# [EKF PRED] t+0.015s -> [ 1.16012876 -0.00711619  0.87780077]  can_reach=False v_req=82.73416811872332 meas_z=0.883 ekf_z=0.882
# [EKF PRED] t+0.015s -> [ 1.16528173 -0.00868619  0.87635632]  can_reach=False v_req=82.94765436605543 meas_z=0.882 ekf_z=0.881
# [EKF PRED] t+0.015s -> [ 1.16534835 -0.00869225  0.87688922]  can_reach=False v_req=82.97369835613718 meas_z=0.882 ekf_z=0.881
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0710). Flipping Z to 0.0710
# [EKF PRED] t+0.015s -> [ 1.16537098 -0.00869431  0.87707025]  can_reach=False v_req=83.50552987243127 meas_z=0.882 ekf_z=0.881
# [EKF PRED] t+0.015s -> [ 1.16538237 -0.00869534  0.87716141]  can_reach=False v_req=83.51003575178831 meas_z=0.882 ekf_z=0.881
# [EKF PRED] t+0.015s -> [ 1.16744144 -0.01117428  0.86734976]  can_reach=False v_req=83.22965390272266 meas_z=0.874 ekf_z=0.874
# [EKF PRED] t+0.015s -> [ 1.16739459 -0.01118913  0.86781231]  can_reach=False v_req=83.24754231820779 meas_z=0.874 ekf_z=0.874
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0828). Flipping Z to 0.0828
# [EKF PRED] t+0.015s -> [ 1.16737863 -0.01119419  0.86796986]  can_reach=False v_req=83.051666381959 meas_z=0.874 ekf_z=0.874
# [EKF PRED] t+0.015s -> [ 1.17580863 -0.00193878  0.8562641 ]  can_reach=False v_req=82.79710271234696 meas_z=0.864 ekf_z=0.863
# [EKF PRED] t+0.015s -> [ 1.1758509  -0.00618845  0.85343732]  can_reach=False v_req=82.75480254920689 meas_z=0.858 ekf_z=0.861
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0776). Flipping Z to 0.0776
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0606). Flipping Z to 0.0606
# [EKF PRED] t+0.015s -> [ 1.17586508 -0.00761381  0.8524892 ]  can_reach=False v_req=82.75757796743298 meas_z=0.858 ekf_z=0.860
# [EKF PRED] t+0.015s -> [ 1.17880176 -0.00652789  0.84894997]  can_reach=False v_req=82.73217502788275 meas_z=0.855 ekf_z=0.854
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0579). Flipping Z to 0.0579
# [EKF PRED] t+0.015s -> [ 1.1793233  -0.01059299  0.84686724]  can_reach=False v_req=82.74369047960036 meas_z=0.851 ekf_z=0.853
# [EKF PRED] t+0.015s -> [ 1.17950005 -0.01197064  0.84616141]  can_reach=False v_req=83.06267906128512 meas_z=0.851 ekf_z=0.852
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0522). Flipping Z to 0.0522
# [EKF PRED] t+0.015s -> [ 1.17958898 -0.01266378  0.84580628]  can_reach=False v_req=83.2074646817679 meas_z=0.851 ekf_z=0.852
# [EKF PRED] t+0.015s -> [ 1.17964251 -0.01308106  0.84559249]  can_reach=False v_req=83.20867323405284 meas_z=0.851 ekf_z=0.852
# [EKF PRED] t+0.015s -> [ 1.18204116 -0.0089211   0.8418799 ]  can_reach=False v_req=83.09208802130728 meas_z=0.848 ekf_z=0.847
# [EKF PRED] t+0.015s -> [ 1.18238269 -0.00995339  0.84188912]  can_reach=False v_req=83.12778110576122 meas_z=0.847 ekf_z=0.847
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0939). Flipping Z to 0.0939
# [EKF PRED] t+0.015s -> [ 1.18249897 -0.01030485  0.84189225]  can_reach=False v_req=82.54461535304077 meas_z=0.847 ekf_z=0.847
# [EKF PRED] t+0.015s -> [ 1.18255758 -0.010482    0.84189383]  can_reach=False v_req=82.55071466961284 meas_z=0.847 ekf_z=0.847
# [EKF PRED] t+0.015s -> [ 1.18385456 -0.00985431  0.84041266]  can_reach=False v_req=82.54205785280757 meas_z=0.846 ekf_z=0.845
# [EKF PRED] t+0.015s -> [ 1.18419759 -0.0110762   0.84044666]  can_reach=False v_req=82.58209886415281 meas_z=0.845 ekf_z=0.845
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0662). Flipping Z to 0.0662
# [EKF PRED] t+0.015s -> [ 1.18431513 -0.01149488  0.84045831]  can_reach=False v_req=83.0480167722748 meas_z=0.845 ekf_z=0.845
# [EKF PRED] t+0.015s -> [ 1.18437452 -0.01170642  0.84046419]  can_reach=False v_req=83.05499415596768 meas_z=0.845 ekf_z=0.845
# [EKF PRED] t+0.015s -> [ 1.18514704 -0.01175969  0.83951902]  can_reach=False v_req=83.05407087981382 meas_z=0.845 ekf_z=0.844
# [EKF PRED] t+0.015s -> [ 1.18504561 -0.01260591  0.83941738]  can_reach=False v_req=83.06028363843092 meas_z=0.843 ekf_z=0.844
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0779). Flipping Z to 0.0779
# [EKF PRED] t+0.015s -> [ 1.18525492 -0.01367628  0.83894362]  can_reach=False v_req=82.87935359706212 meas_z=0.842 ekf_z=0.843
# [EKF PRED] t+0.015s -> [ 1.18536039 -0.01421563  0.83870489]  can_reach=False v_req=82.8843897641607 meas_z=0.842 ekf_z=0.843
# [EKF PRED] t+0.015s -> [ 1.18676577 -0.01233674  0.83464347]  can_reach=False v_req=82.75104391458898 meas_z=0.840 ekf_z=0.839
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0813). Flipping Z to 0.0813
# [EKF PRED] t+0.015s -> [ 1.18677168 -0.01227076  0.83519056]  can_reach=False v_req=82.7193413694054 meas_z=0.840 ekf_z=0.840
# [EKF PRED] t+0.015s -> [ 1.18677369 -0.01224832  0.83537669]  can_reach=False v_req=82.72672061578514 meas_z=0.840 ekf_z=0.840
# [EKF PRED] t+0.015s -> [ 1.19360114 -0.01102422  0.82142077]  can_reach=False v_req=82.46999039964349 meas_z=0.830 ekf_z=0.829
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0740). Flipping Z to 0.0740
# [EKF PRED] t+0.015s -> [ 1.19361254 -0.01103019  0.82169897]  can_reach=False v_req=82.16112629379688 meas_z=0.830 ekf_z=0.829
# [EKF PRED] t+0.015s -> [ 1.19361635 -0.01103219  0.82179205]  can_reach=False v_req=82.16509953447576 meas_z=0.830 ekf_z=0.829
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0858). Flipping Z to 0.0858
# [EKF PRED] t+0.015s -> [ 1.19960737 -0.00330384  0.81776523]  can_reach=False v_req=82.09505114578697 meas_z=0.824 ekf_z=0.823
# [EKF PRED] t+0.015s -> [ 1.20077117 -0.01759158  0.80785021]  can_reach=False v_req=82.02283958308739 meas_z=0.808 ekf_z=0.816
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0687). Flipping Z to 0.0687
# [EKF PRED] t+0.015s -> [ 1.2011653  -0.02243012  0.8044925 ]  can_reach=False v_req=82.26258327210309 meas_z=0.808 ekf_z=0.813
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0657). Flipping Z to 0.0657
# [EKF PRED] t+0.015s -> [ 1.20136354 -0.02486389  0.80280358]  can_reach=False v_req=82.35841132083968 meas_z=0.808 ekf_z=0.812
# [EKF PRED] t+0.015s -> [ 1.20172688 -0.03012853  0.79898005]  can_reach=False v_req=82.32718792193161 meas_z=0.797 ekf_z=0.809
# [EKF PRED] t+0.015s -> [ 1.21058598 -0.03277496  0.77920254]  can_reach=False v_req=82.05313611499125 meas_z=0.788 ekf_z=0.787
# [EKF PRED] t+0.015s -> [ 1.21056925 -0.03264842  0.77967142]  can_reach=False v_req=82.06787949191401 meas_z=0.788 ekf_z=0.787
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0919). Flipping Z to 0.0919
# [EKF PRED] t+0.015s -> [ 1.21056364 -0.03260595  0.7798288 ]  can_reach=False v_req=81.7568992701931 meas_z=0.788 ekf_z=0.788
# [EKF PRED] t+0.015s -> [ 1.21111181 -0.03676118  0.77695552]  can_reach=False v_req=81.76091131649929 meas_z=0.778 ekf_z=0.785
# [EKF PRED] t+0.015s -> [ 1.21704328 -0.04399632  0.7668379 ]  can_reach=False v_req=81.83363843241249 meas_z=0.774 ekf_z=0.774
# [EKF PRED] t+0.015s -> [ 1.21704346 -0.04404832  0.76742899]  can_reach=False v_req=81.85678375619294 meas_z=0.774 ekf_z=0.774
# [EKF PRED] t+0.015s -> [ 1.21813235 -0.04128982  0.7669306 ]  can_reach=False v_req=81.83620596032105 meas_z=0.773 ekf_z=0.771
# [EKF PRED] t+0.015s -> [ 1.21800394 -0.04084811  0.76826909]  can_reach=False v_req=81.87038732600524 meas_z=0.773 ekf_z=0.772
# [EKF PRED] t+0.015s -> [ 1.21926986 -0.05296699  0.75977881]  can_reach=False v_req=81.8761970301336 meas_z=0.767 ekf_z=0.766
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0798). Flipping Z to 0.0798
# [EKF PRED] t+0.015s -> [ 1.21923755 -0.05379928  0.76026831]  can_reach=False v_req=81.75227006489541 meas_z=0.767 ekf_z=0.766
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0671). Flipping Z to 0.0671
# [EKF PRED] t+0.015s -> [ 1.21884756 -0.05238941  0.76051419]  can_reach=False v_req=81.99083024431462 meas_z=0.767 ekf_z=0.765
# [EKF PRED] t+0.015s -> [ 1.21871616 -0.05165217  0.76197566]  can_reach=False v_req=82.02336312109273 meas_z=0.767 ekf_z=0.766
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0879). Flipping Z to 0.0879
# [EKF PRED] t+0.015s -> [ 1.21866747 -0.051379    0.76251718]  can_reach=False v_req=81.93203938672684 meas_z=0.767 ekf_z=0.766
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0952). Flipping Z to 0.0952
# [EKF PRED] t+0.015s -> [ 1.21892708 -0.05446897  0.76039581]  can_reach=False v_req=81.6185094681806 meas_z=0.760 ekf_z=0.765
# [EKF PRED] t+0.015s -> [ 1.2190864  -0.05636527  0.75909393]  can_reach=False v_req=81.61996110635158 meas_z=0.760 ekf_z=0.764
# [EKF PRED] t+0.015s -> [ 1.22257859 -0.05839208  0.75273205]  can_reach=False v_req=81.61394991747412 meas_z=0.759 ekf_z=0.758
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0817). Flipping Z to 0.0817
# [EKF PRED] t+0.015s -> [ 1.22293103 -0.06025624  0.75192118]  can_reach=False v_req=81.71073380210848 meas_z=0.757 ekf_z=0.757
# [EKF PRED] t+0.015s -> [ 1.22305065 -0.06088896  0.75164596]  can_reach=False v_req=81.72076590767776 meas_z=0.757 ekf_z=0.757
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0618). Flipping Z to 0.0618
# [EKF PRED] t+0.015s -> [ 1.22311087 -0.06120749  0.7515074 ]  can_reach=False v_req=82.08608788559842 meas_z=0.757 ekf_z=0.757
# [EKF PRED] t+0.015s -> [ 1.22150757 -0.06049632  0.75161492]  can_reach=False v_req=81.99262492517796 meas_z=0.757 ekf_z=0.755
# [EKF PRED] t+0.015s -> [ 1.22139847 -0.06039407  0.75243226]  can_reach=False v_req=82.01500532022163 meas_z=0.757 ekf_z=0.756
# [EKF PRED] t+0.015s -> [ 1.22136095 -0.06035889  0.75271342]  can_reach=False v_req=82.02271129564396 meas_z=0.757 ekf_z=0.756
# [EKF PRED] t+0.015s -> [ 1.22134196 -0.0603411   0.75285569]  can_reach=False v_req=82.026612092977 meas_z=0.757 ekf_z=0.756
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0696). Flipping Z to 0.0696
# [EKF PRED] t+0.015s -> [ 1.22138415 -0.05962043  0.75355054]  can_reach=False v_req=81.949429416867 meas_z=0.759 ekf_z=0.757
# [EKF PRED] t+0.015s -> [ 1.21906907 -0.05927006  0.75402686]  can_reach=False v_req=81.84050598162058 meas_z=0.760 ekf_z=0.760
# [EKF PRED] t+0.015s -> [ 1.21918913 -0.05773986  0.75563935]  can_reach=False v_req=81.87391781846905 meas_z=0.762 ekf_z=0.761
# [EKF PRED] t+0.015s -> [ 1.22085269 -0.05583515  0.75789589]  can_reach=False v_req=82.00288520092109 meas_z=0.762 ekf_z=0.761
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0605). Flipping Z to 0.0605
# [EKF PRED] t+0.015s -> [ 1.22094807 -0.05577484  0.75882151]  can_reach=False v_req=82.1449789576928 meas_z=0.762 ekf_z=0.762
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0827). Flipping Z to 0.0827
# [EKF PRED] t+0.015s -> [ 1.2209817  -0.05575357  0.75914786]  can_reach=False v_req=82.14863066883835 meas_z=0.762 ekf_z=0.762
# [EKF PRED] t+0.015s -> [ 1.22000641 -0.05755671  0.75913062]  can_reach=False v_req=82.13516418638196 meas_z=0.763 ekf_z=0.762
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0736). Flipping Z to 0.0736
# [EKF PRED] t+0.015s -> [ 1.21998408 -0.05596626  0.76170395]  can_reach=False v_req=82.33413410078492 meas_z=0.766 ekf_z=0.764
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0830). Flipping Z to 0.0830
# [EKF PRED] t+0.015s -> [ 1.21997578 -0.05537494  0.76266069]  can_reach=False v_req=82.357354474359 meas_z=0.766 ekf_z=0.764
# [EKF PRED] t+0.015s -> [ 1.22138862 -0.0544134   0.76086271]  can_reach=False v_req=82.08318459675463 meas_z=0.766 ekf_z=0.765
# [EKF PRED] t+0.015s -> [ 1.22142962 -0.05442158  0.76135382]  can_reach=False v_req=82.10361497359156 meas_z=0.766 ekf_z=0.765
# [EKF PRED] t+0.015s -> [ 1.22178917 -0.05406028  0.76205026]  can_reach=False v_req=82.14014115953232 meas_z=0.767 ekf_z=0.766
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1207). Flipping Z to 0.1207
# [EKF PRED] t+0.015s -> [ 1.22197067 -0.05387789  0.76240182]  can_reach=False v_req=81.54947146650379 meas_z=0.767 ekf_z=0.766
# [EKF PRED] t+0.015s -> [ 1.22205378 -0.05411318  0.76231839]  can_reach=False v_req=81.55564414391651 meas_z=0.766 ekf_z=0.766
# [EKF PRED] t+0.015s -> [ 1.22474477 -0.05355215  0.75834212]  can_reach=False v_req=81.54213069199031 meas_z=0.764 ekf_z=0.764
# [EKF PRED] t+0.015s -> [ 1.22474278 -0.05355984  0.75870091]  can_reach=False v_req=81.55502492110921 meas_z=0.764 ekf_z=0.764
# [EKF PRED] t+0.015s -> [ 1.22474211 -0.05356242  0.75882133]  can_reach=False v_req=81.55935384199134 meas_z=0.764 ekf_z=0.764
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0805). Flipping Z to 0.0805
# [EKF PRED] t+0.015s -> [ 1.22474177 -0.05356372  0.7588817 ]  can_reach=False v_req=82.06249346423363 meas_z=0.764 ekf_z=0.764
# [EKF PRED] t+0.015s -> [ 1.22474157 -0.05356449  0.75891797]  can_reach=False v_req=82.06382962922895 meas_z=0.764 ekf_z=0.764
# [EKF PRED] t+0.015s -> [ 1.22572892 -0.05086729  0.75671768]  can_reach=False v_req=81.97758603934582 meas_z=0.762 ekf_z=0.761
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0589). Flipping Z to 0.0589
# [EKF PRED] t+0.015s -> [ 1.22571952 -0.05083479  0.75727179]  can_reach=False v_req=82.2798878443541 meas_z=0.762 ekf_z=0.762
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0788). Flipping Z to 0.0788
# [EKF PRED] t+0.015s -> [ 1.22571633 -0.05082375  0.75745981]  can_reach=False v_req=82.30863809468276 meas_z=0.762 ekf_z=0.762
# [EKF PRED] t+0.015s -> [ 1.22654699 -0.05132876  0.75645213]  can_reach=False v_req=82.32423897905859 meas_z=0.762 ekf_z=0.762
# [EKF PRED] t+0.015s -> [ 1.22654298 -0.05135152  0.75684279]  can_reach=False v_req=82.33900130965658 meas_z=0.762 ekf_z=0.762
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0704). Flipping Z to 0.0704
# [EKF PRED] t+0.015s -> [ 1.22654163 -0.05135916  0.75697388]  can_reach=False v_req=82.2084636846668 meas_z=0.762 ekf_z=0.762
# [EKF PRED] t+0.015s -> [ 1.22654096 -0.05136299  0.75703959]  can_reach=False v_req=82.21093211480203 meas_z=0.762 ekf_z=0.762
# [EKF PRED] t+0.015s -> [ 1.22917237 -0.05186909  0.75444252]  can_reach=False v_req=82.26157915545187 meas_z=0.760 ekf_z=0.759
# [EKF PRED] t+0.015s -> [ 1.22921295 -0.05186944  0.7550223 ]  can_reach=False v_req=82.28498500423704 meas_z=0.760 ekf_z=0.759
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0649). Flipping Z to 0.0649
# [EKF PRED] t+0.015s -> [ 1.2293138  -0.05292317  0.75611538]  can_reach=False v_req=82.41376746457843 meas_z=0.761 ekf_z=0.759
# [EKF PRED] t+0.015s -> [ 1.22951447 -0.05606748  0.75492705]  can_reach=False v_req=82.44512722729955 meas_z=0.758 ekf_z=0.759
# [EKF PRED] t+0.015s -> [ 1.22958708 -0.05720517  0.75449708]  can_reach=False v_req=82.45662166563386 meas_z=0.758 ekf_z=0.758
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0763). Flipping Z to 0.0763
# [EKF PRED] t+0.015s -> [ 1.23026699 -0.0568256   0.75075634]  can_reach=False v_req=82.37821368845589 meas_z=0.757 ekf_z=0.755
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0751). Flipping Z to 0.0751
# [EKF PRED] t+0.015s -> [ 1.23007498 -0.05599102  0.751139  ]  can_reach=False v_req=82.25238202003264 meas_z=0.757 ekf_z=0.755
# [EKF PRED] t+0.015s -> [ 1.23002325 -0.05589095  0.75210531]  can_reach=False v_req=82.28289268679859 meas_z=0.757 ekf_z=0.756
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0837). Flipping Z to 0.0837
# [EKF PRED] t+0.015s -> [ 1.23056161 -0.05752226  0.75148408]  can_reach=False v_req=82.32232463633005 meas_z=0.754 ekf_z=0.755
# [EKF PRED] t+0.015s -> [ 1.230839   -0.05836278  0.75116399]  can_reach=False v_req=82.24686729255012 meas_z=0.754 ekf_z=0.755
# [EKF PRED] t+0.015s -> [ 1.23555987 -0.05772267  0.74744124]  can_reach=False v_req=82.34384851203633 meas_z=0.753 ekf_z=0.752
# [EKF PRED] t+0.015s -> [ 1.23559684 -0.05768148  0.74794988]  can_reach=False v_req=82.36325306896973 meas_z=0.753 ekf_z=0.753
# [EKF PRED] t+0.015s -> [ 1.23633099 -0.06048609  0.74632496]  can_reach=False v_req=82.4018446702594 meas_z=0.749 ekf_z=0.751
# [WARN] kreo2 tag5 mean_corner_z negative (-0.1000). Flipping Z to 0.1000
# [EKF PRED] t+0.015s -> [ 1.23670014 -0.06189634  0.7455079 ]  can_reach=False v_req=82.1557361246649 meas_z=0.749 ekf_z=0.751
# [EKF PRED] t+0.015s -> [ 1.2369223  -0.06274505  0.74501617]  can_reach=False v_req=82.16844315341211 meas_z=0.749 ekf_z=0.750
# [EKF PRED] t+0.015s -> [ 1.24266602 -0.0710144   0.73636147]  can_reach=False v_req=82.34726268006314 meas_z=0.743 ekf_z=0.742
# [EKF PRED] t+0.015s -> [ 1.24265823 -0.07104099  0.73679018]  can_reach=False v_req=82.36236187788897 meas_z=0.743 ekf_z=0.743
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0658). Flipping Z to 0.0658
# [EKF PRED] t+0.015s -> [ 1.24527622 -0.06791373  0.73600276]  can_reach=False v_req=82.75455128748514 meas_z=0.742 ekf_z=0.740
# [EKF PRED] t+0.015s -> [ 1.246953   -0.07354886  0.7333246 ]  can_reach=False v_req=82.8676110858729 meas_z=0.737 ekf_z=0.739
# [EKF PRED] t+0.015s -> [ 1.24755648 -0.07557699  0.73236071]  can_reach=False v_req=82.90881203131066 meas_z=0.737 ekf_z=0.738
# [EKF PRED] t+0.015s -> [ 1.24831886 -0.07677198  0.72856301]  can_reach=False v_req=82.84101003492793 meas_z=0.735 ekf_z=0.734
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0747). Flipping Z to 0.0747
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0590). Flipping Z to 0.0590
# [EKF PRED] t+0.015s -> [ 1.2497858  -0.07509683  0.7297446 ]  can_reach=False v_req=83.11234366087561 meas_z=0.735 ekf_z=0.734
# [EKF PRED] t+0.015s -> [ 1.24975831 -0.07488185  0.7308003 ]  can_reach=False v_req=83.14373156068835 meas_z=0.735 ekf_z=0.734
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0794). Flipping Z to 0.0794
# [EKF PRED] t+0.015s -> [ 1.25054919 -0.0778868   0.72920766]  can_reach=False v_req=83.19337630510559 meas_z=0.731 ekf_z=0.733
# [EKF PRED] t+0.015s -> [ 1.25095553 -0.07943069  0.72838939]  can_reach=False v_req=83.1498197277022 meas_z=0.731 ekf_z=0.733
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0906). Flipping Z to 0.0906
# [EKF PRED] t+0.015s -> [ 1.25274495 -0.08064544  0.72393786]  can_reach=False v_req=82.81093279036527 meas_z=0.730 ekf_z=0.729
# [EKF PRED] t+0.015s -> [ 1.25270313 -0.08059267  0.72447919]  can_reach=False v_req=82.82611824568242 meas_z=0.730 ekf_z=0.729
# [EKF PRED] t+0.015s -> [ 1.25309808 -0.08374486  0.72233337]  can_reach=False v_req=82.8444835342346 meas_z=0.724 ekf_z=0.728
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1080). Flipping Z to 0.1080
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0708). Flipping Z to 0.0708
# [EKF PRED] t+0.015s -> [ 1.25329681 -0.08533094  0.72125366]  can_reach=False v_req=82.71838139383553 meas_z=0.724 ekf_z=0.727
# [EKF PRED] t+0.015s -> [ 1.25389475 -0.08995837  0.72003323]  can_reach=False v_req=82.8104496641045 meas_z=0.725 ekf_z=0.724
# [EKF PRED] t+0.015s -> [ 1.25386888 -0.08996132  0.72078398]  can_reach=False v_req=82.8345646965699 meas_z=0.725 ekf_z=0.725
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0946). Flipping Z to 0.0946
# [EKF PRED] t+0.015s -> [ 1.25378707 -0.09111424  0.72003632]  can_reach=False v_req=82.93696704530154 meas_z=0.723 ekf_z=0.724
# [EKF PRED] t+0.015s -> [ 1.25374572 -0.09169698  0.71965842]  can_reach=False v_req=82.93492668698184 meas_z=0.723 ekf_z=0.724
# [EKF PRED] t+0.015s -> [ 1.25017664 -0.0933922   0.7195736 ]  can_reach=False v_req=82.78216331157229 meas_z=0.724 ekf_z=0.723
# [EKF PRED] t+0.015s -> [ 1.25010409 -0.09330079  0.72022754]  can_reach=False v_req=82.79865623641929 meas_z=0.724 ekf_z=0.724
# [EKF PRED] t+0.015s -> [ 1.24948259 -0.09285004  0.7203686 ]  can_reach=False v_req=82.76065168501589 meas_z=0.724 ekf_z=0.724
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0711). Flipping Z to 0.0711
# [EKF PRED] t+0.015s -> [ 1.24916917 -0.09262272  0.72043973]  can_reach=False v_req=83.08096440480513 meas_z=0.724 ekf_z=0.724
# [EKF PRED] t+0.015s -> [ 1.2475554  -0.08828553  0.72293892]  can_reach=False v_req=82.98559014920389 meas_z=0.734 ekf_z=0.726
# [EKF PRED] t+0.015s -> [ 1.24647646 -0.08538575  0.72460984]  can_reach=False v_req=82.9225902289205 meas_z=0.734 ekf_z=0.727
# [EKF PRED] t+0.015s -> [ 1.22979852 -0.08189932  0.73390193]  can_reach=False v_req=82.30886565722857 meas_z=0.739 ekf_z=0.738
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0794). Flipping Z to 0.0794
# [EKF PRED] t+0.015s -> [ 1.22856487 -0.07547278  0.73857969]  can_reach=False v_req=82.13257462840936 meas_z=0.747 ekf_z=0.742
# [EKF PRED] t+0.015s -> [ 1.2272081  -0.06677618  0.74480644]  can_reach=False v_req=82.09834204080111 meas_z=0.759 ekf_z=0.748
# [EKF PRED] t+0.015s -> [ 1.2265288  -0.06242205  0.74792399]  can_reach=False v_req=82.08356196871044 meas_z=0.759 ekf_z=0.751
# [EKF PRED] t+0.015s -> [ 1.21120836 -0.06369296  0.76596239]  can_reach=False v_req=81.9917774913286 meas_z=0.767 ekf_z=0.766
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0659). Flipping Z to 0.0659
# [EKF PRED] t+0.015s -> [ 1.20790129 -0.04659738  0.7780247 ]  can_reach=False v_req=82.1268949212114 meas_z=0.785 ekf_z=0.776
# [EKF PRED] t+0.015s -> [ 1.20484906 -0.02580201  0.79276894]  can_reach=False v_req=82.12867625518672 meas_z=0.811 ekf_z=0.787
# [EKF PRED] t+0.015s -> [ 1.1488422  -0.05542658  0.85960808]  can_reach=False v_req=82.73666206829759 meas_z=0.854 ekf_z=0.853
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0733). Flipping Z to 0.0733
# [EKF PRED] t+0.015s -> [ 1.14868028 -0.05588565  0.86007345]  can_reach=False v_req=82.75846010630823 meas_z=0.854 ekf_z=0.853
# [EKF PRED] t+0.015s -> [ 1.14862588 -0.05603989  0.8602298 ]  can_reach=False v_req=82.73837750767503 meas_z=0.854 ekf_z=0.853
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0941). Flipping Z to 0.0941
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0817). Flipping Z to 0.0817
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0607). Flipping Z to 0.0607
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0641). Flipping Z to 0.0641
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0870). Flipping Z to 0.0870
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0698). Flipping Z to 0.0698
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0890). Flipping Z to 0.0890
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0773). Flipping Z to 0.0773
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0819). Flipping Z to 0.0819
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0852). Flipping Z to 0.0852
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0622). Flipping Z to 0.0622
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0793). Flipping Z to 0.0793
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0821). Flipping Z to 0.0821
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0688). Flipping Z to 0.0688
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0805). Flipping Z to 0.0805
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0631). Flipping Z to 0.0631
# [EKF] large Z jump: meas_z=0.651, pred_z=-2.415 -> resetting velocities
# [EKF PRED] t+0.015s -> [0.52750714 0.67828434 0.72688738]  can_reach=False v_req=52.4190435447912 meas_z=0.651 ekf_z=0.651
# [EKF PRED] t+0.015s -> [0.5275066  0.67829453 0.72691734]  can_reach=False v_req=52.420999674255526 meas_z=0.651 ekf_z=0.651
# [EKF PRED] t+0.015s -> [0.52750642 0.67829792 0.72692732]  can_reach=False v_req=52.42165172834569 meas_z=0.651 ekf_z=0.651
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0808). Flipping Z to 0.0808
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0751). Flipping Z to 0.0751
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0793). Flipping Z to 0.0793
# [EKF] large Z jump: meas_z=0.002, pred_z=1.184 -> resetting velocities
# [EKF PRED] t+0.015s -> [ 0.39060091  0.65742174 -0.16048419]  can_reach=False v_req=28.004472649018364 meas_z=0.002 ekf_z=0.003
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0751). Flipping Z to 0.0751
# [EKF PRED] t+0.015s -> [ 0.39051965  0.65729508 -0.1613409 ]  can_reach=False v_req=28.02819650222187 meas_z=0.002 ekf_z=0.002
# [EKF PRED] t+0.015s -> [ 0.39049255  0.65725282 -0.16162671]  can_reach=False v_req=28.036326178541348 meas_z=0.002 ekf_z=0.002
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0822). Flipping Z to 0.0822
# [EKF] large Z jump: meas_z=0.062, pred_z=-0.705 -> resetting velocities
# [EKF] measurement gated out d2=50.26
# [EKF PRED] t+0.015s -> [ 0.34072261  0.57966939 -0.70607876]  can_reach=False v_req=55.071486653294485 meas_z=0.062 ekf_z=-0.705
# [EKF] large Z jump: meas_z=0.062, pred_z=-0.705 -> resetting velocities
# [EKF] measurement gated out d2=50.26
# [EKF PRED] t+0.015s -> [ 0.34072261  0.57966939 -0.70607876]  can_reach=False v_req=55.071486653294485 meas_z=0.062 ekf_z=-0.705
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0711). Flipping Z to 0.0711
# [EKF] large Z jump: meas_z=0.062, pred_z=-0.705 -> resetting velocities
# [EKF] measurement gated out d2=50.26
# [EKF PRED] t+0.015s -> [ 0.34072261  0.57966939 -0.70607876]  can_reach=False v_req=54.98117871587279 meas_z=0.062 ekf_z=-0.705
# [EKF] large Z jump: meas_z=0.085, pred_z=-0.728 -> resetting velocities
# [EKF PRED] t+0.015s -> [0.51635462 0.58347223 0.22495716]  can_reach=False v_req=25.500441782078195 meas_z=0.085 ekf_z=0.084
# [EKF PRED] t+0.015s -> [0.5165145  0.58347569 0.22582604]  can_reach=False v_req=25.529907294712856 meas_z=0.085 ekf_z=0.085
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0752). Flipping Z to 0.0752
# [EKF PRED] t+0.015s -> [0.51656786 0.58347684 0.22611601]  can_reach=False v_req=25.471085269106204 meas_z=0.085 ekf_z=0.085
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0820). Flipping Z to 0.0820
# [EKF] large Z jump: meas_z=0.032, pred_z=1.080 -> resetting velocities
# [EKF] measurement gated out d2=20.22
# [EKF PRED] t+0.015s -> [0.68462874 0.58711575 1.07862042]  can_reach=False v_req=74.2525433225687 meas_z=0.032 ekf_z=1.080
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0691). Flipping Z to 0.0691
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0715). Flipping Z to 0.0715
# [EKF] large Z jump: meas_z=-0.014, pred_z=1.063 -> resetting velocities
# [EKF PRED] t+0.015s -> [ 0.58565353  0.44297058 -0.15538325]  can_reach=False v_req=26.629437756706363 meas_z=-0.014 ekf_z=-0.013
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0847). Flipping Z to 0.0847
# [EKF PRED] t+0.015s -> [ 0.58929399  0.43709341 -0.1638714 ]  can_reach=False v_req=27.037351906829095 meas_z=-0.028 ekf_z=-0.020
# [EKF PRED] t+0.015s -> [ 0.59050846  0.43513277 -0.16670308]  can_reach=False v_req=27.67843900282578 meas_z=-0.028 ekf_z=-0.023
# [EKF PRED] t+0.015s -> [ 0.59111587  0.43415215 -0.16811934]  can_reach=False v_req=27.74872755129664 meas_z=-0.028 ekf_z=-0.024
# [EKF] large Z jump: meas_z=0.007, pred_z=-0.914 -> resetting velocities
# [EKF] measurement gated out d2=17.78
# [EKF PRED] t+0.015s -> [ 0.53723978  0.34602436 -0.91553701]  can_reach=False v_req=68.56619567694625 meas_z=0.007 ekf_z=-0.914
# [EKF] large Z jump: meas_z=0.007, pred_z=-0.914 -> resetting velocities
# [EKF] measurement gated out d2=17.78
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0767). Flipping Z to 0.0767
# [EKF PRED] t+0.015s -> [ 0.53723978  0.34602436 -0.91553701]  can_reach=False v_req=68.56619567694625 meas_z=0.007 ekf_z=-0.914
# [EKF] large Z jump: meas_z=0.007, pred_z=-0.914 -> resetting velocities
# [EKF] measurement gated out d2=17.78
# [EKF PRED] t+0.015s -> [ 0.53723978  0.34602436 -0.91553701]  can_reach=False v_req=68.28756363057016 meas_z=0.007 ekf_z=-0.914
# [EKF] large Z jump: meas_z=0.007, pred_z=-0.914 -> resetting velocities
# [EKF] measurement gated out d2=17.78
# [EKF PRED] t+0.015s -> [ 0.53723978  0.34602436 -0.91553701]  can_reach=False v_req=68.28756363057016 meas_z=0.007 ekf_z=-0.914
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0748). Flipping Z to 0.0748
# [EKF] large Z jump: meas_z=-0.028, pred_z=-0.963 -> resetting velocities
# [EKF PRED] t+0.015s -> [0.69508992 0.30470281 0.07011444]  can_reach=False v_req=28.160935106932243 meas_z=-0.028 ekf_z=-0.028
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0658). Flipping Z to 0.0658
# [EKF PRED] t+0.015s -> [0.69514172 0.30468925 0.07045385]  can_reach=False v_req=28.16390533181793 meas_z=-0.028 ekf_z=-0.028
# [EKF PRED] t+0.015s -> [0.695159   0.30468473 0.07056704]  can_reach=False v_req=28.165076745705264 meas_z=-0.028 ekf_z=-0.028
# [EKF] large Z jump: meas_z=-0.000, pred_z=0.329 -> resetting velocities
# [EKF PRED] t+0.015s -> [ 0.66783053  0.28143971 -0.0894254 ]  can_reach=False v_req=28.551769123020648 meas_z=-0.000 ekf_z=0.006
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1182). Flipping Z to 0.1182
# [EKF PRED] t+0.015s -> [ 0.66975358  0.26966613 -0.10948071]  can_reach=False v_req=30.380584516813187 meas_z=-0.022 ekf_z=-0.009
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0890). Flipping Z to 0.0890
# [EKF PRED] t+0.015s -> [ 0.67030175  0.26631    -0.1151976 ]  can_reach=False v_req=30.607171785542825 meas_z=-0.022 ekf_z=-0.014
# [EKF] large Z jump: meas_z=-0.007, pred_z=-0.405 -> resetting velocities
# [EKF PRED] t+0.015s -> [0.70635934 0.25559911 0.09896806]  can_reach=False v_req=29.840035392130822 meas_z=-0.007 ekf_z=-0.009
# [EKF PRED] t+0.015s -> [0.70659573 0.25561865 0.10051101]  can_reach=False v_req=29.854504302047804 meas_z=-0.007 ekf_z=-0.008
# [EKF PRED] t+0.015s -> [0.70738128 0.24946559 0.09275211]  can_reach=False v_req=29.981580564394385 meas_z=-0.026 ekf_z=-0.014
# [EKF PRED] t+0.015s -> [0.70777466 0.24638435 0.08886673]  can_reach=False v_req=30.050498499232972 meas_z=-0.026 ekf_z=-0.017
# [EKF] large Z jump: meas_z=-0.004, pred_z=0.614 -> resetting velocities
# [EKF PRED] t+0.015s -> [ 0.6729041   0.21678977 -0.11362752]  can_reach=False v_req=31.696617894425902 meas_z=-0.004 ekf_z=-0.001
# [EKF PRED] t+0.015s -> [ 0.67259606  0.21672495 -0.11541414]  can_reach=False v_req=31.734595932187553 meas_z=-0.004 ekf_z=-0.002
# [EKF PRED] t+0.015s -> [ 0.67217632  0.20886794 -0.12680339]  can_reach=False v_req=32.1906301838789 meas_z=-0.031 ekf_z=-0.012
# [EKF PRED] t+0.015s -> [ 0.68829882  0.18371275 -0.04213732]  can_reach=False v_req=31.35850490453738 meas_z=-0.023 ekf_z=-0.029
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0710). Flipping Z to 0.0710
# [EKF PRED] t+0.015s -> [ 0.69131589  0.18099522 -0.02105473]  can_reach=False v_req=30.918081988711783 meas_z=-0.015 ekf_z=-0.020
# [EKF PRED] t+0.015s -> [ 0.69091164  0.17146288 -0.03253191]  can_reach=False v_req=31.28733982091673 meas_z=-0.037 ekf_z=-0.028
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0832). Flipping Z to 0.0832
# [EKF PRED] t+0.015s -> [ 0.69076591  0.16802658 -0.0366693 ]  can_reach=False v_req=30.878914893277035 meas_z=-0.037 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.69031677  0.16161476 -0.03679   ]  can_reach=False v_req=31.00586226161751 meas_z=-0.031 ekf_z=-0.033
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0590). Flipping Z to 0.0590
# [EKF PRED] t+0.015s -> [ 0.69024383  0.16257758 -0.03541825]  can_reach=False v_req=30.77773493912808 meas_z=-0.031 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.69021725  0.16292852 -0.03491825]  can_reach=False v_req=30.76020239387824 meas_z=-0.031 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.6893861   0.14564408 -0.02993424]  can_reach=False v_req=31.061556493543453 meas_z=-0.026 ekf_z=-0.027
# [EKF PRED] t+0.015s -> [ 0.6893795   0.14565515 -0.02924851]  can_reach=False v_req=31.050996020709867 meas_z=-0.026 ekf_z=-0.027
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0659). Flipping Z to 0.0659
# [EKF PRED] t+0.015s -> [ 0.69000633  0.14369655 -0.02543298]  can_reach=False v_req=31.173162938478185 meas_z=-0.022 ekf_z=-0.024
# [EKF PRED] t+0.015s -> [ 0.68957403  0.1440689  -0.0236585 ]  can_reach=False v_req=31.112521238754233 meas_z=-0.020 ekf_z=-0.021
# [EKF PRED] t+0.015s -> [ 0.68852757  0.14351927 -0.02451621]  can_reach=False v_req=31.07662766338696 meas_z=-0.022 ekf_z=-0.022
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0848). Flipping Z to 0.0848
# [EKF PRED] t+0.015s -> [ 0.68770494  0.14347793 -0.02748248]  can_reach=False v_req=31.072630188987517 meas_z=-0.022 ekf_z=-0.023
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0732). Flipping Z to 0.0732
# [EKF PRED] t+0.015s -> [ 0.68770046  0.14360684 -0.026825  ]  can_reach=False v_req=31.18381103643758 meas_z=-0.022 ekf_z=-0.023
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0621). Flipping Z to 0.0621
# [EKF PRED] t+0.015s -> [ 0.68769881  0.14365437 -0.02658258]  can_reach=False v_req=30.935120769846723 meas_z=-0.022 ekf_z=-0.023
# [EKF PRED] t+0.015s -> [ 0.68769795  0.1436791  -0.02645648]  can_reach=False v_req=30.9326776418371 meas_z=-0.022 ekf_z=-0.023
# ...
# [EKF PRED] t+0.015s -> [ 0.67489187  0.17507239 -0.03797925]  can_reach=False v_req=29.93240136898612 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0799). Flipping Z to 0.0799
# [EKF PRED] t+0.015s -> [ 0.67489256  0.175072   -0.03791357]  can_reach=False v_req=29.93126174274889 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.6748929   0.1750718  -0.03788071]  can_reach=False v_req=29.675613667166537 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67482758  0.17524644 -0.03484799]  can_reach=False v_req=29.617057983723015 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67482465  0.17525419 -0.03432472]  can_reach=False v_req=29.60810365216105 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0736). Flipping Z to 0.0736
# [EKF PRED] t+0.015s -> [ 0.67482366  0.17525681 -0.03414816]  can_reach=False v_req=29.683371504872532 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67482316  0.17525813 -0.03405948]  can_reach=False v_req=29.681838278645166 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0669). Flipping Z to 0.0669
# [EKF PRED] t+0.015s -> [ 0.67482287  0.17525892 -0.03400613]  can_reach=False v_req=29.572055434590975 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67482267  0.17525944 -0.03397052]  can_reach=False v_req=29.571456172855864 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67483255  0.17523268 -0.03647913]  can_reach=False v_req=29.613609708264665 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67483276  0.17523213 -0.03619055]  can_reach=False v_req=29.608879863069294 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0796). Flipping Z to 0.0796
# [EKF PRED] t+0.015s -> [ 0.67483283  0.17523195 -0.03609402]  can_reach=False v_req=29.596926957237304 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67534728  0.17728339 -0.03757505]  can_reach=False v_req=29.605605889899394 meas_z=-0.032 ekf_z=-0.033
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0568). Flipping Z to 0.0568
# [EKF PRED] t+0.015s -> [ 0.67537234  0.17738513 -0.03669372]  can_reach=False v_req=29.428032794495643 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0760). Flipping Z to 0.0760
# [EKF PRED] t+0.015s -> [ 0.67538125  0.17742131 -0.03638033]  can_reach=False v_req=29.37654714649907 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67538582  0.17743986 -0.03621968]  can_reach=False v_req=29.373913204746298 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67518295  0.17663666 -0.03683649]  can_reach=False v_req=29.389201173290388 meas_z=-0.032 ekf_z=-0.033
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0671). Flipping Z to 0.0671
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1097). Flipping Z to 0.1097
# [EKF PRED] t+0.015s -> [ 0.67516889  0.17658094 -0.03623648]  can_reach=False v_req=30.10624738126999 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67516413  0.17656204 -0.03603293]  can_reach=False v_req=30.10261704434619 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67516173  0.17655253 -0.03593048]  can_reach=False v_req=30.100791949731324 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0606). Flipping Z to 0.0606
# [EKF PRED] t+0.015s -> [ 0.67475479  0.17493953 -0.03485893]  can_reach=False v_req=29.977066387260894 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67475371  0.17493523 -0.03441834]  can_reach=False v_req=29.969265690167457 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67475334  0.17493378 -0.03427   ]  can_reach=False v_req=29.966645281009274 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0933). Flipping Z to 0.0933
# [EKF PRED] t+0.015s -> [ 0.67475316  0.17493306 -0.03419555]  can_reach=False v_req=29.649245724540545 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67483522  0.17525833 -0.03483461]  can_reach=False v_req=29.657696501122622 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67484077  0.17528035 -0.03429584]  can_reach=False v_req=29.64854291313398 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0763). Flipping Z to 0.0763
# [EKF PRED] t+0.015s -> [ 0.67484266  0.17528783 -0.03411284]  can_reach=False v_req=29.645443045560437 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67445847  0.17534774 -0.03410853]  can_reach=False v_req=29.395008202727755 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67422707  0.17538382 -0.03410593]  can_reach=False v_req=29.380106097612217 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67393311  0.17731958 -0.03765174]  can_reach=False v_req=29.374151344928276 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67470283  0.17723218 -0.03693703]  can_reach=False v_req=29.411378661879265 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0689). Flipping Z to 0.0689
# [EKF PRED] t+0.015s -> [ 0.67496466  0.17720244 -0.03669391]  can_reach=False v_req=29.554502878751187 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0582). Flipping Z to 0.0582
# [EKF PRED] t+0.015s -> [ 0.67480109  0.17484201 -0.03506791]  can_reach=False v_req=29.572756212984583 meas_z=-0.030 ekf_z=-0.031
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1174). Flipping Z to 0.1174
# [EKF PRED] t+0.015s -> [ 0.6747947   0.17481499 -0.03465205]  can_reach=False v_req=30.049496205570172 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67479256  0.17480592 -0.03451243]  can_reach=False v_req=30.04702433853726 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0826). Flipping Z to 0.0826
# [EKF PRED] t+0.015s -> [ 0.67532499  0.17709818 -0.03745674]  can_reach=False v_req=30.08657358282815 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67537042  0.17732999 -0.03667106]  can_reach=False v_req=29.503843615069247 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0579). Flipping Z to 0.0579
# [EKF PRED] t+0.015s -> [ 0.67473178  0.17485879 -0.03439141]  can_reach=False v_req=29.50946428095544 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67470857  0.17476852 -0.03371263]  can_reach=False v_req=29.49943517164693 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67470067  0.17473778 -0.03348149]  can_reach=False v_req=29.496035512589827 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0767). Flipping Z to 0.0767
# [EKF PRED] t+0.015s -> [ 0.67469669  0.17472229 -0.03336499]  can_reach=False v_req=29.40708348041785 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67469429  0.17471296 -0.03329479]  can_reach=False v_req=29.406084748275664 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67486488  0.17537255 -0.03615572]  can_reach=False v_req=29.44538745558821 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67486936  0.17538985 -0.03584636]  can_reach=False v_req=29.440437315309214 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0665). Flipping Z to 0.0665
# [EKF PRED] t+0.015s -> [ 0.67531943  0.17717714 -0.03733661]  can_reach=False v_req=29.315022633898252 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67532544  0.1772013  -0.03670426]  can_reach=False v_req=29.305307478494427 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.6753275   0.17720956 -0.03648799]  can_reach=False v_req=29.30199803410589 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0688). Flipping Z to 0.0688
# [EKF PRED] t+0.015s -> [ 0.67532854  0.17721373 -0.0363788 ]  can_reach=False v_req=29.44161914370096 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0905). Flipping Z to 0.0905
# [EKF PRED] t+0.015s -> [ 0.67519837  0.17669758 -0.03674561]  can_reach=False v_req=29.79658477250619 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67518762  0.17665495 -0.03609432]  can_reach=False v_req=29.785609566586604 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0670). Flipping Z to 0.0670
# [EKF PRED] t+0.015s -> [ 0.67518395  0.17664041 -0.03587218]  can_reach=False v_req=29.74822753068942 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67518211  0.17663308 -0.03576014]  can_reach=False v_req=29.746361030696725 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67473838  0.17487452 -0.03444687]  can_reach=False v_req=29.73646829438891 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67476902  0.17499597 -0.03487578]  can_reach=False v_req=29.742860863904898 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67478563  0.17506181 -0.03402298]  can_reach=False v_req=29.727960891452188 meas_z=-0.030 ekf_z=-0.031
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0713). Flipping Z to 0.0713
# [EKF PRED] t+0.015s -> [ 0.67531547  0.17716169 -0.03732364]  can_reach=False v_req=29.84533262390682 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67535358  0.1773127  -0.03662132]  can_reach=False v_req=29.831930854688082 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0848). Flipping Z to 0.0848
# [EKF PRED] t+0.015s -> [ 0.67536739  0.17736743 -0.0363668 ]  can_reach=False v_req=29.725482057695384 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67527289  0.17699292 -0.03706025]  can_reach=False v_req=29.740187985515032 meas_z=-0.032 ekf_z=-0.033
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1130). Flipping Z to 0.1130
# [EKF PRED] t+0.015s -> [ 0.67523895  0.17685842 -0.03595964]  can_reach=False v_req=30.20617930052425 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67522657  0.17680932 -0.03555782]  can_reach=False v_req=30.19890462867713 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67522015  0.17678388 -0.03534964]  can_reach=False v_req=30.195144592968184 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67520259  0.1767143  -0.03749444]  can_reach=False v_req=30.236125123028877 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67447955  0.17681924 -0.03726184]  can_reach=False v_req=30.185884378808414 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0687). Flipping Z to 0.0687
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0895). Flipping Z to 0.0895
# [EKF PRED] t+0.015s -> [ 0.67423649  0.17685452 -0.03718365]  can_reach=False v_req=29.730772748200486 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67411458  0.17687221 -0.03714443]  can_reach=False v_req=29.722343118892052 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67544068  0.17669352 -0.03701066]  can_reach=False v_req=29.804007164517518 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67546117  0.17669124 -0.03652957]  can_reach=False v_req=29.796980432051893 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67546809  0.17669047 -0.03636727]  can_reach=False v_req=29.794617367755258 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67547156  0.17669009 -0.03628575]  can_reach=False v_req=29.7934318982408 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67472627  0.17479162 -0.03404729]  can_reach=False v_req=29.753358643613375 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67524966  0.17699217 -0.03719831]  can_reach=False v_req=29.789018080046027 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67529057  0.17714578 -0.03662546]  can_reach=False v_req=29.778115321204776 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0661). Flipping Z to 0.0661
# [EKF PRED] t+0.015s -> [ 0.67481083  0.17520645 -0.0349096 ]  can_reach=False v_req=29.724688354014926 meas_z=-0.030 ekf_z=-0.032
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0799). Flipping Z to 0.0799
# [EKF PRED] t+0.015s -> [ 0.67523943  0.17685937 -0.03690065]  can_reach=False v_req=29.612388259666492 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67527399  0.1769921  -0.03629096]  can_reach=False v_req=29.60142206880118 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0679). Flipping Z to 0.0679
# [EKF PRED] t+0.015s -> [ 0.67525931  0.17693404 -0.03711659]  can_reach=False v_req=29.639992705134667 meas_z=-0.032 ekf_z=-0.033
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0686). Flipping Z to 0.0686
# [EKF PRED] t+0.015s -> [ 0.67524278  0.17686989 -0.03606657]  can_reach=False v_req=29.453525344519257 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67472989  0.17484135 -0.03440217]  can_reach=False v_req=29.44444221870368 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.6739631   0.17491622 -0.03398558]  can_reach=False v_req=29.389953733274684 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1222). Flipping Z to 0.1222
# [EKF PRED] t+0.015s -> [ 0.67370248  0.17494166 -0.03384398]  can_reach=False v_req=30.201070985491175 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.673626    0.17550682 -0.03593562]  can_reach=False v_req=30.224634388541837 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67363729  0.17552462 -0.03557065]  can_reach=False v_req=30.217923010123517 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0911). Flipping Z to 0.0911
# [EKF PRED] t+0.015s -> [ 0.67412208  0.17546048 -0.03533837]  can_reach=False v_req=29.70456126445461 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0803). Flipping Z to 0.0803
# [EKF PRED] t+0.015s -> [ 0.67436516  0.17542832 -0.03522189]  can_reach=False v_req=29.92822344108896 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67545556  0.17709202 -0.0373105 ]  can_reach=False v_req=29.99319424916165 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67546273  0.17710823 -0.03677195]  can_reach=False v_req=29.98345535739721 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67546516  0.17711372 -0.03658925]  can_reach=False v_req=29.980160464662823 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0672). Flipping Z to 0.0672
# [EKF PRED] t+0.015s -> [ 0.67546639  0.17711649 -0.03649729]  can_reach=False v_req=29.65194487872231 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67546713  0.17711816 -0.03644191]  can_reach=False v_req=29.651034100052314 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67517084  0.17667435 -0.03692895]  can_reach=False v_req=29.652054584411452 meas_z=-0.032 ekf_z=-0.033
# [EKF PRED] t+0.015s -> [ 0.67515428  0.17664944 -0.03639516]  can_reach=False v_req=29.64282890798849 meas_z=-0.032 ekf_z=-0.032
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0774). Flipping Z to 0.0774
# [EKF PRED] t+0.015s -> [ 0.67464739  0.17671421 -0.0363292 ]  can_reach=False v_req=29.746267079465213 meas_z=-0.032 ekf_z=-0.032
# [EKF PRED] t+0.015s -> [ 0.67343087  0.17514461 -0.03541085]  can_reach=False v_req=29.69476966666904 meas_z=-0.030 ekf_z=-0.031
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0513). Flipping Z to 0.0513
# [EKF PRED] t+0.015s -> [ 0.67415122  0.17503304 -0.03484338]  can_reach=False v_req=29.282897385210436 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67439322  0.17499556 -0.03465273]  can_reach=False v_req=29.295615688216344 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.0781). Flipping Z to 0.0781
# [EKF PRED] t+0.015s -> [ 0.67451458  0.17497677 -0.03455713]  can_reach=False v_req=29.31222285917421 meas_z=-0.030 ekf_z=-0.030
# [EKF PRED] t+0.015s -> [ 0.67491851  0.17522453 -0.03464613]  can_reach=False v_req=29.332598822333505 meas_z=-0.030 ekf_z=-0.031
# [EKF PRED] t+0.015s -> [ 0.67492762  0.17525026 -0.03401965]  can_reach=False v_req=29.32317403747827 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo1 tag4 mean_corner_z negative (-0.1161). Flipping Z to 0.1161
# [EKF PRED] t+0.015s -> [ 0.67493074  0.17525907 -0.03380525]  can_reach=False v_req=29.319961549596098 meas_z=-0.030 ekf_z=-0.030
# [WARN] kreo2 tag5 mean_corner_z negative (-0.0706). Flipping Z to 0.0706
# [DETECT-kreo2] AprilTag Detector thread stopped
# [kreo2] BallDetectorThread stopped
# [DETECT-kreo1] AprilTag Detector thread stopped
# [kreo1] BallDetectorThread stopped
# Exit clean.
